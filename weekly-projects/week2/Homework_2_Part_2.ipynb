# %%
# Homework 2 Part 2 (due 7/07/2024)

# %% [markdown]
# # Health-care assistance via probabilistic graphical modeling
#
# ### Objective
# In this project, you will create a health-care assistance bot that can suggest diagnoses for a set of symptoms based on a probabilistic graphical model.
#
# ### Step 1: Review
# Review the code from the Bayesian networks exercise.
#
# ### Step 2: Acquire data
# View this [research article](https://www.nature.com/articles/ncomms5212) and download its supplementary data sets 1, 2 and 3. These data sets include the occurrences of diseases, symptoms, and their co-occurrences in the scientific literature. (For the purpose of this exercise, we are going to assume that the frequency of co-occurrences of diseases and symptoms in scientific papers is proportional to the co-occurence frequencies of actual disease cases and symptoms.)
#
# ### Step 3: Create a Bayesian network
# Using commands from the `pgmpy` library, create a Bayesian network in which the probability of exhibiting a symptom is conditional on the probability of having an associated disease.
#
# ### Step 4: Initialize priors
# Use the disease occurrence data to assign prior probabilities for diseases.
#
# ### Step 5: Calculate conditional probability tables
# Use the co-occurrence data to define CPTs for each connected pair of disease and symptoms. (Hint: You may need to assign some occurrences of symptoms to an "idiopathic disease" to create valid CPTs.)
#
# ### Step 6:
# Create a minimal interface in which your bot asks a users for a list of observed symptoms and then returns the name of the disease that is the most likely match to the symptoms. (Hint: Review the input/output commands that you have used in last week's homework.)

# %%
#import libraries
# !pip install pgmpy
import pandas as pd
import numpy as np
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination
from collections import defaultdict
import networkx as nx


#from google.colab import drive
#drive.mount('/content/drive')

#import dataset
path1 = '/content/drive/My Drive/data1.txt'
path2 = '/content/drive/My Drive/data2.txt'
path3 = '/content/drive/My Drive/data3.txt'

# Load the datasets
data1 = pd.read_csv(path1, delimiter='\t')
data2 = pd.read_csv(path2, delimiter='\t')
data3 = pd.read_csv(path3, delimiter='\t')
# Out:
# Collecting pgmpy
#   Downloading pgmpy-0.1.25-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pgmpy) (3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pgmpy) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pgmpy) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pgmpy) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pgmpy) (2.0.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from pgmpy) (3.1.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pgmpy) (2.3.0+cu121)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from pgmpy) (0.14.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pgmpy) (4.66.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from pgmpy) (3.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pgmpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pgmpy) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pgmpy) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels->pgmpy) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels->pgmpy) (24.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy) (1.12.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->pgmpy)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->pgmpy)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->pgmpy)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->pgmpy)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->pgmpy)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->pgmpy)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->pgmpy)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->pgmpy)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->pgmpy)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->pgmpy)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->pgmpy)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->pgmpy) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->pgmpy)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 41.4 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels->pgmpy) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->pgmpy) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pgmpy) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, pgmpy
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 pgmpy-0.1.25
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-0fbddaaf5a34> in <cell line: 21>()
#      19
#      20 # Load the datasets
# ---> 21 data1 = pd.read_csv(path1, delimiter='\t')
#      22 data2 = pd.read_csv(path2, delimiter='\t')
#      23 data3 = pd.read_csv(path3, delimiter='\t')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     575
#     576     # Create the parser.
# --> 577     parser = TextFileReader(filepath_or_buffer, **kwds)
#     578
#     579     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1405
#    1406         self.handles: IOHandles | None = None
# -> 1407         self._engine = self._make_engine(f, self.engine)
#    1408
#    1409     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1659                 if "b" not in mode:
#    1660                     mode += "b"
# -> 1661             self.handles = get_handle(
#    1662                 f,
#    1663                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857         if ioargs.encoding and "b" not in ioargs.mode:
#     858             # Encoding
# --> 859             handle = open(
#     860                 handle,
#     861                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/data1.txt'

# %%
import pandas as pd

# Function to clean data1
def clean_data1(df):
    if 'MeSH Disease Term' in df.columns and 'PubMed occurrence' in df.columns:
        # Keep rows with 'PubMed occurrence' > 300
        df = df[df['PubMed occurrence'] > 300]
    return df

# Function to clean data2
def clean_data2(df):
    if 'MeSH Symptom Term' in df.columns and 'PubMed occurrence' in df.columns:
        # Keep rows with 'PubMed occurrence' > 300
        df = df[df['PubMed occurrence'] > 300]
    return df

def clean_data3(df):
    # Check if necessary columns exist before processing
    if 'MeSH Symptom Term' in df.columns and 'MeSH Disease Term' in df.columns and 'PubMed occurrence' in df.columns:
        # Drop rows with missing values in these key columns
        df = df.dropna(subset=['MeSH Symptom Term', 'MeSH Disease Term', 'PubMed occurrence'])

        # Convert 'PubMed occurrence' to numeric and filter for occurrences >= 300
        df['PubMed occurrence'] = pd.to_numeric(df['PubMed occurrence'], errors='coerce')
        df = df[df['PubMed occurrence'] >= 300]

    return df

# Apply cleaning functions
data1 = clean_data1(data1)
data2 = clean_data2(data2)
data3 = clean_data3(data3)

# Display the cleaned data to verify
print(data1.head())
print(data2.head())
print(data3.head())

# %%
import pandas as pd
import networkx as nx
from pgmpy.models import BayesianNetwork

# Function to clean data1
def clean_data1(df):
    if 'MeSH Disease Term' in df.columns and 'PubMed occurrence' in df.columns:
        df = df[df['PubMed occurrence'] > 300]
    return df

# Function to clean data2
def clean_data2(df):
    if 'MeSH Symptom Term' in df.columns and 'PubMed occurrence' in df.columns:
        df = df[df['PubMed occurrence'] > 300]
    return df

def clean_data3(df):
    if 'MeSH Symptom Term' in df.columns and 'MeSH Disease Term' in df.columns and 'PubMed occurrence' in df.columns:
        df = df.dropna(subset=['MeSH Symptom Term', 'MeSH Disease Term', 'PubMed occurrence'])
        df['PubMed occurrence'] = pd.to_numeric(df['PubMed occurrence'], errors='coerce')
        df = df[df['PubMed occurrence'] >= 300]
    return df

# Load datasets
data1 = pd.read_csv('/content/drive/My Drive/data1.txt', delimiter='\t')
data2 = pd.read_csv('/content/drive/My Drive/data2.txt', delimiter='\t')
data3 = pd.read_csv('/content/drive/My Drive/data3.txt', delimiter='\t')

# Apply cleaning functions
data1 = clean_data1(data1)
data2 = clean_data2(data2)
data3 = clean_data3(data3)

# Display the cleaned data to verify
print(data1.head())
print(data2.head())
print(data3.head())

# Define the Bayesian Network structure
model = BayesianNetwork()

# Add nodes (filtered diseases and symptoms)
diseases = data1['MeSH Disease Term'].unique()
symptoms = data2['MeSH Symptom Term'].unique()

model.add_nodes_from(diseases)
model.add_nodes_from(symptoms)

# Function to check if there is a path from start to end
def is_reachable(graph, start, end):
    try:
        return nx.has_path(graph, start, end)
    except nx.NetworkXError:
        return False

# Add edges from diseases to symptoms, avoiding self-loops and ensuring both nodes exist in the model
existing_edges = set()
for _, row in data3.iterrows():
    disease = row['MeSH Disease Term']
    symptom = row['MeSH Symptom Term']

    # Ensure both nodes exist in the model
    if disease not in model.nodes() or symptom not in model.nodes():
        continue

    # Avoid self-loops
    if disease == symptom:
        continue

    # Check if adding this edge would form a loop
    if disease != symptom and (symptom, disease) not in existing_edges:
        # Check for existing path from symptom to disease to avoid cycles
        if not is_reachable(model, symptom, disease):
            model.add_edge(disease, symptom)
            existing_edges.add((disease, symptom))

# Print the nodes and edges in the Bayesian Network
print("Nodes in the Bayesian Network:")
print(model.nodes())

print("Edges in the Bayesian Network:")
print(model.edges())
# Out:
#          MeSH Disease Term  PubMed occurrence
# 0         Breast Neoplasms             122226
# 1             Hypertension             107294
# 2  Coronary Artery Disease              82819
# 3           Lung Neoplasms              78009
# 4    Myocardial Infarction              75945
#     MeSH Symptom Term  PubMed occurrence
# 0         Body Weight             147857
# 1                Pain             103168
# 2             Obesity             100301
# 3              Anoxia              47351
# 4  Mental Retardation              43883
#      MeSH Symptom Term     MeSH Disease Term  PubMed occurrence  TFIDF score
# 668              Fever  Bacterial Infections                651   402.928399
# 837              Fever             Infection                397   245.718240
# 869              Fever                Sepsis                326   201.773668
# 2420             Fever           Neutropenia               1236   765.006914
# 4996       Body Weight      Breast Neoplasms                373   127.934467
# Nodes in the Bayesian Network:
# ['Breast Neoplasms', 'Hypertension', 'Coronary Artery Disease', 'Lung Neoplasms', 'Myocardial Infarction', 'HIV Infections', 'Coronary Disease', 'Asthma', 'Adenocarcinoma', 'Dementia', 'Prostatic Neoplasms', 'Skin Neoplasms', 'Obesity', 'Carcinoma, Squamous Cell', 'Pain', 'Liver Neoplasms', 'Arthritis, Rheumatoid', 'Schizophrenia', 'Diabetes Mellitus, Type 2', 'Brain Neoplasms', 'Heart Failure', 'Postoperative Complications', 'Kidney Failure, Chronic', 'Alzheimer Disease', 'Diabetes Mellitus', 'Stomach Neoplasms', 'Diabetes Mellitus, Type 1', 'Ovarian Neoplasms', 'Melanoma', 'Kidney Diseases', 'Myocardial Ischemia', 'Depressive Disorder', 'Epilepsy', 'Carcinoma', 'Cerebral Infarction', 'Tuberculosis, Pulmonary', 'Acquired Immunodeficiency Syndrome', 'Uterine Cervical Neoplasms', 'Lung Diseases', 'Kidney Neoplasms', 'Alcoholism', 'Colorectal Neoplasms', 'Carcinoma, Hepatocellular', 'Colonic Neoplasms', 'Parkinson Disease', 'Bacterial Infections', 'Liver Diseases', 'Pancreatic Neoplasms', 'Lupus Erythematosus, Systemic', 'Dog Diseases', 'Arteriosclerosis', 'Liver Cirrhosis', 'Arrhythmias, Cardiac', 'Skin Diseases', 'Brain Diseases', 'Leukemia', 'Multiple Sclerosis', 'Substance-Related Disorders', 'Urinary Bladder Neoplasms', 'Inflammation', 'Heart Diseases', 'Pregnancy Complications', 'Lymphoma', 'Cognition Disorders', 'Thrombosis', 'Head and Neck Neoplasms', 'Stroke', 'Autoimmune Diseases', 'Cattle Diseases', 'Pancreatitis', 'Bone Neoplasms', 'Brain Injuries', 'Osteoporosis', 'Sepsis', 'Brain Ischemia', 'Thyroid Neoplasms', 'Burns', 'Hepatitis C', 'Diabetes Mellitus, Experimental', 'Cerebrovascular Disorders', 'Adenoma', 'Cystic Fibrosis', 'Multiple Myeloma', 'Neoplasms, Experimental', 'Tuberculosis', 'Hodgkin Disease', 'Carcinoma, Non-Small-Cell Lung', 'Ischemia', 'Seizures', 'Uterine Neoplasms', 'Esophageal Neoplasms', 'Leukemia, Myeloid, Acute', 'Staphylococcal Infections', 'Acute Kidney Injury', 'Psoriasis', 'Crohn Disease', 'Lymphoma, Non-Hodgkin', 'Bipolar Disorder', 'Hemorrhage', 'Abnormalities, Multiple', 'Mental Retardation', 'Gastrointestinal Hemorrhage', 'Neoplasm Recurrence, Local', 'Glioma', 'Hypersensitivity', 'Atrial Fibrillation', 'Pneumonia', 'Fractures, Bone', 'Helicobacter Infections', 'Calcinosis', 'Psychotic Disorders', 'Heart Defects, Congenital', 'Spinal Cord Injuries', 'Common Cold', 'Angina Pectoris', 'Pulmonary Embolism', 'Urinary Tract Infections', 'Hepatitis', 'Colitis, Ulcerative', 'Fetal Diseases', 'Rectal Neoplasms', 'Cysts', 'Hepatitis B', 'Glomerulonephritis', 'Gallstones', 'Glaucoma', 'Leukemia, Myeloid', 'Respiratory Tract Infections', 'Anemia', 'Infection', 'Hypertension, Pulmonary', 'Mouth Neoplasms', 'Horse Diseases', 'Infant, Newborn, Diseases', 'Arterial Occlusive Diseases', 'Precursor Cell Lymphoblastic Leukemia-Lymphoma', 'Respiratory Insufficiency', 'Gastrointestinal Diseases', 'Toxemia', 'Malaria', 'Leukemia, Lymphoid', 'Testicular Neoplasms', 'Cardiomyopathies', 'Hyperthyroidism', 'Streptococcal Infections', 'Sarcoidosis', 'Carcinoma, Renal Cell', 'Pre-Eclampsia', 'Hypothyroidism', 'Peptic Ulcer', 'Osteoarthritis', 'Migraine Disorders', 'Hyperlipidemias', 'Cerebral Hemorrhage', 'Arthritis', 'Neuroblastoma', 'Down Syndrome', 'Attention Deficit Disorder with Hyperactivity', 'Precancerous Conditions', 'Pituitary Neoplasms', 'Neoplasms, Multiple Primary', 'Infertility, Female', 'Amyloidosis', 'Foreign Bodies', 'Muscular Diseases', 'Peripheral Nervous System Diseases', 'Lung Diseases, Obstructive', 'Laryngeal Neoplasms', 'Intestinal Obstruction', 'Stress Disorders, Post-Traumatic', 'Heart Arrest', 'Pulmonary Disease, Chronic Obstructive', 'Pregnancy Complications, Infectious', 'Cytomegalovirus Infections', 'Vascular Diseases', 'Cataract', 'Stomach Ulcer', 'Hemophilia A', 'Cholelithiasis', 'Hypercholesterolemia', 'Anemia, Sickle Cell', 'Duodenal Ulcer', 'Hepatitis C, Chronic', 'Shock, Septic', 'Intracranial Aneurysm', 'Scleroderma, Diffuse', 'Cat Diseases', 'Poultry Diseases', 'Anxiety Dis ...
# Edges in the Bayesian Network:
# [('Breast Neoplasms', 'Body Weight'), ('Breast Neoplasms', 'Obesity'), ('Breast Neoplasms', 'Fatigue'), ('Breast Neoplasms', 'Pain'), ('Breast Neoplasms', 'Nausea'), ('Hypertension', 'Body Weight'), ('Hypertension', 'Birth Weight'), ('Hypertension', 'Weight Loss'), ('Hypertension', 'Obesity'), ('Hypertension', 'Angina Pectoris'), ('Hypertension', 'Proteinuria'), ('Hypertension', 'Albuminuria'), ('Coronary Artery Disease', 'Body Weight'), ('Coronary Artery Disease', 'Obesity'), ('Coronary Artery Disease', 'Pain'), ('Coronary Artery Disease', 'Chest Pain'), ('Coronary Artery Disease', 'Angina Pectoris'), ('Coronary Artery Disease', 'Acute Coronary Syndrome'), ('Coronary Artery Disease', 'Angina, Unstable'), ('Coronary Artery Disease', 'Anoxia'), ('Lung Neoplasms', 'Dyspnea'), ('Lung Neoplasms', 'Hemoptysis'), ('Myocardial Infarction', 'Body Weight'), ('Myocardial Infarction', 'Pain'), ('Myocardial Infarction', 'Chest Pain'), ('Myocardial Infarction', 'Angina Pectoris'), ('Myocardial Infarction', 'Acute Coronary Syndrome'), ('Myocardial Infarction', 'Angina, Unstable'), ('HIV Infections', 'Diarrhea'), ('Coronary Disease', 'Body Weight'), ('Coronary Disease', 'Obesity'), ('Coronary Disease', 'Pain'), ('Coronary Disease', 'Chest Pain'), ('Coronary Disease', 'Angina Pectoris'), ('Coronary Disease', 'Angina, Unstable'), ('Coronary Disease', 'Anoxia'), ('Asthma', 'Obesity'), ('Asthma', 'Cough'), ('Asthma', 'Dyspnea'), ('Asthma', 'Respiratory Sounds'), ('Dementia', 'Psychomotor Agitation'), ('Dementia', 'Memory Disorders'), ('Dementia', 'Amnesia'), ('Prostatic Neoplasms', 'Pain'), ('Obesity', 'Body Weight'), ('Obesity', 'Birth Weight'), ('Obesity', 'Weight Gain'), ('Obesity', 'Weight Loss'), ('Obesity', 'Overweight'), ('Obesity', 'Obesity, Morbid'), ('Obesity', 'Thinness'), ('Obesity', 'Hyperphagia'), ('Pain', 'Edema'), ('Pain', 'Back Pain'), ('Pain', 'Headache'), ('Pain', 'Psychophysiologic Disorders'), ('Pain', 'Pain, Postoperative'), ('Arthritis, Rheumatoid', 'Pain'), ('Schizophrenia', 'Weight Gain'), ('Schizophrenia', 'Memory Disorders'), ('Schizophrenia', 'Hallucinations'), ('Diabetes Mellitus, Type 2', 'Body Weight'), ('Diabetes Mellitus, Type 2', 'Weight Gain'), ('Diabetes Mellitus, Type 2', 'Weight Loss'), ('Diabetes Mellitus, Type 2', 'Obesity'), ('Diabetes Mellitus, Type 2', 'Proteinuria'), ('Diabetes Mellitus, Type 2', 'Albuminuria'), ('Brain Neoplasms', 'Headache'), ('Brain Neoplasms', 'Seizures'), ('Heart Failure', 'Body Weight'), ('Heart Failure', 'Cardiac Output, Low'), ('Heart Failure', 'Edema'), ('Heart Failure', 'Dyspnea'), ('Postoperative Complications', 'Pain, Postoperative'), ('Kidney Failure, Chronic', 'Body Weight'), ('Kidney Failure, Chronic', 'Proteinuria'), ('Alzheimer Disease', 'Memory Disorders'), ('Diabetes Mellitus', 'Body Weight'), ('Diabetes Mellitus', 'Obesity'), ('Diabetes Mellitus', 'Albuminuria'), ('Diabetes Mellitus, Type 1', 'Body Weight'), ('Diabetes Mellitus, Type 1', 'Obesity'), ('Diabetes Mellitus, Type 1', 'Proteinuria'), ('Diabetes Mellitus, Type 1', 'Albuminuria'), ('Ovarian Neoplasms', 'Virilism'), ('Kidney Diseases', 'Body Weight'), ('Kidney Diseases', 'Colic'), ('Kidney Diseases', 'Proteinuria'), ('Kidney Diseases', 'Albuminuria'), ('Myocardial Ischemia', 'Obesity'), ('Myocardial Ischemia', 'Chest Pain'), ('Myocardial Ischemia', 'Angina Pectoris'), ('Myocardial Ischemia', 'Acute Coronary Syndrome'), ('Myocardial Ischemia', 'Angina, Unstable'), ('Depressive Disorder', 'Pain'), ('Epilepsy', 'Myoclonus'), ('Epilepsy', 'Mental Retardation'), ('Epilepsy', 'Seizures'), ('Cerebral Infarction', 'Aphasia'), ('Cerebral Infarction', 'Muscle Weakness'), ('Cerebral Infarction', 'Hemiplegia'), ('Cerebral Infarction', 'Paresis'), ('Acquired Immunodeficiency Syndrome', 'Diarrhea'), ('Lung Diseases', 'Anoxia'), ('Lung Diseases', 'Dyspnea'), ('Lung Diseases', 'Hemoptysis'), ('Parkinson Disease', 'Tremor'), ('Parkinson Disease', 'Hallucinations'), ('Parkinson Disease', 'Muscle Rigidity'), ('Bacterial Infect ...

# %%
merged_data = pd.merge(data3, data1[['MeSH Disease Term', 'PubMed occurrence']],
                       left_on='MeSH Disease Term', right_on='MeSH Disease Term', suffixes=('', '_Disease'))

# Merge with data2 to get the symptom occurrence
merged_data = pd.merge(merged_data, data2[['MeSH Symptom Term', 'PubMed occurrence']],
                       left_on='MeSH Symptom Term', right_on='MeSH Symptom Term', suffixes=('', '_Symptom'))

# Calculate the conditional probability P(Symptom|Disease)
merged_data['P(Symptom|Disease)'] = merged_data['PubMed occurrence'] / merged_data['PubMed occurrence_Disease']

# Display the results
print(merged_data[['MeSH Disease Term', 'MeSH Symptom Term', 'P(Symptom|Disease)']])
# Out:
#                MeSH Disease Term            MeSH Symptom Term  \
# 0           Bacterial Infections                        Fever
# 1                      Infection                        Fever
# 2                         Sepsis                        Fever
# 3                    Neutropenia                        Fever
# 4           Bacterial Infections                     Diarrhea
# ..                           ...                          ...
# 528                     Oliguria                     Oliguria
# 529                     Polyuria                     Polyuria
# 530               Hemoglobinuria               Hemoglobinuria
# 531  Urinary Bladder, Overactive  Urinary Bladder, Overactive
# 532            Ovarian Neoplasms                     Virilism
#
#      P(Symptom|Disease)
# 0              0.023215
# 1              0.030087
# 2              0.015753
# 3              0.187956
# 4              0.015726
# ..                  ...
# 528            1.000000
# 529            1.000000
# 530            1.000000
# 531            1.000000
# 532            0.008481
#
# [533 rows x 3 columns]

# %%
# Function to compute the conditional probability for a specific pair
def compute_conditional_probability(disease, symptom, df):
    subset = df[(df['MeSH Disease Term'] == disease) & (df['MeSH Symptom Term'] == symptom)]
    if not subset.empty:
        cooccurrence = subset['PubMed occurrence'].values[0]
        disease_occurrence = subset['PubMed occurrence_Disease'].values[0]
        return cooccurrence / disease_occurrence
    else:
        return None

# Compute and print the conditional probabilities for all disease-symptom pairs
for disease in diseases:
    for symptom in symptoms:
        conditional_prob = compute_conditional_probability(disease, symptom, merged_data)
        if conditional_prob is not None:
            print(f"The conditional probability P({symptom}|{disease}) is {conditional_prob:.2f}")
# Out:
# The conditional probability P(Body Weight|Breast Neoplasms) is 0.00
# The conditional probability P(Pain|Breast Neoplasms) is 0.00
# The conditional probability P(Obesity|Breast Neoplasms) is 0.00
# The conditional probability P(Fatigue|Breast Neoplasms) is 0.00
# The conditional probability P(Nausea|Breast Neoplasms) is 0.00
# The conditional probability P(Body Weight|Hypertension) is 0.03
# The conditional probability P(Obesity|Hypertension) is 0.03
# The conditional probability P(Angina Pectoris|Hypertension) is 0.00
# The conditional probability P(Birth Weight|Hypertension) is 0.00
# The conditional probability P(Weight Loss|Hypertension) is 0.00
# The conditional probability P(Proteinuria|Hypertension) is 0.01
# The conditional probability P(Albuminuria|Hypertension) is 0.01
# The conditional probability P(Body Weight|Coronary Artery Disease) is 0.01
# The conditional probability P(Pain|Coronary Artery Disease) is 0.00
# The conditional probability P(Obesity|Coronary Artery Disease) is 0.01
# The conditional probability P(Anoxia|Coronary Artery Disease) is 0.00
# The conditional probability P(Angina Pectoris|Coronary Artery Disease) is 0.07
# The conditional probability P(Chest Pain|Coronary Artery Disease) is 0.01
# The conditional probability P(Angina, Unstable|Coronary Artery Disease) is 0.02
# The conditional probability P(Acute Coronary Syndrome|Coronary Artery Disease) is 0.00
# The conditional probability P(Dyspnea|Lung Neoplasms) is 0.00
# The conditional probability P(Hemoptysis|Lung Neoplasms) is 0.00
# The conditional probability P(Body Weight|Myocardial Infarction) is 0.00
# The conditional probability P(Pain|Myocardial Infarction) is 0.00
# The conditional probability P(Angina Pectoris|Myocardial Infarction) is 0.04
# The conditional probability P(Chest Pain|Myocardial Infarction) is 0.01
# The conditional probability P(Angina, Unstable|Myocardial Infarction) is 0.03
# The conditional probability P(Acute Coronary Syndrome|Myocardial Infarction) is 0.00
# The conditional probability P(Diarrhea|HIV Infections) is 0.01
# The conditional probability P(Body Weight|Coronary Disease) is 0.01
# The conditional probability P(Pain|Coronary Disease) is 0.00
# The conditional probability P(Obesity|Coronary Disease) is 0.01
# The conditional probability P(Anoxia|Coronary Disease) is 0.01
# The conditional probability P(Angina Pectoris|Coronary Disease) is 0.07
# The conditional probability P(Chest Pain|Coronary Disease) is 0.01
# The conditional probability P(Angina, Unstable|Coronary Disease) is 0.01
# The conditional probability P(Obesity|Asthma) is 0.00
# The conditional probability P(Dyspnea|Asthma) is 0.01
# The conditional probability P(Cough|Asthma) is 0.01
# The conditional probability P(Respiratory Sounds|Asthma) is 0.02
# The conditional probability P(Memory Disorders|Dementia) is 0.03
# The conditional probability P(Amnesia|Dementia) is 0.01
# The conditional probability P(Psychomotor Agitation|Dementia) is 0.01
# The conditional probability P(Pain|Prostatic Neoplasms) is 0.01
# The conditional probability P(Body Weight|Obesity) is 0.16
# The conditional probability P(Obesity|Obesity) is 0.99
# The conditional probability P(Birth Weight|Obesity) is 0.01
# The conditional probability P(Weight Loss|Obesity) is 0.10
# The conditional probability P(Weight Gain|Obesity) is 0.03
# The conditional probability P(Obesity, Morbid|Obesity) is 0.01
# The conditional probability P(Overweight|Obesity) is 0.03
# The conditional probability P(Thinness|Obesity) is 0.01
# The conditional probability P(Hyperphagia|Obesity) is 0.01
# The conditional probability P(Pain|Pain) is 0.99
# The conditional probability P(Edema|Pain) is 0.01
# The conditional probability P(Pain, Postoperative|Pain) is 0.01
# The conditional probability P(Headache|Pain) is 0.01
# The conditional probability P(Psychophysiologic Disorders|Pain) is 0.01
# The conditional probability P(Back Pain|Pain) is 0.01
# The conditional probability P(Neuralgia|Pain) is 0.01
# The conditional probability P(Hyperalgesia|Pain) is 0.03
# The conditional probability P(Pain|Arthritis, Rheumatoid) is 0.02
# The conditional probability P(Weight Gain|Schizophrenia) is 0.01
# The conditional probability P(Memory Disorders|Schizophrenia) is 0.01
# The conditional probability P(Hallucinations|Schizophrenia) is 0.02
# The conditional probability P(Body Weight|Diabetes Mellitus, Type 2) is 0.03
# The conditional probability P(Obesity|Diabetes Mellitus, Type 2) is 0.10
# The conditional probability P(Weight Loss|Diabetes Mellitus, Type 2) is 0.01
# The conditional probability P(Weight Gain|Diabetes Mellitus, Type 2) is 0.01
# The conditional probability P(Proteinuria|Diabetes Mellitus, Type 2) is 0.01
# The conditional probability P(Albuminuria|Diabetes Mellitus, Type 2) is 0.04
# The conditional probability P(Seizures|Brain Neoplasms) is 0.01
# The conditional probability P(Headache|Brain Neoplasms) is 0.01
# The conditional probability P(Body Weight|Heart Failure) is 0.01
# The conditional probability P(Edema|Heart Failure) is 0.01
# The conditional probability P(Dyspnea|Heart Failure) is 0.01
# The conditional probability P(Cardiac Output, Low|Heart Failure) is 0.01
# The conditional probability P(Pain, Postoperative|Postoperative Complications) is 0.01
# The conditional probability P(Body Weight|Kidney Failure, Chronic) is 0.02
# The conditional probability P(Proteinuria|Kidney Failure, Chronic) is 0.02
# The conditional probability P(Memory Disorders|Alzheimer Disease) is 0.03
# The conditional probability P(Body Weight|Diabetes Mellitus) is 0.03
# The conditional probability P(Obesity|Diabetes Mellitus) is 0.08
# The conditional probability P(Albuminuria|Diabetes Mellitus) is 0.01
# The conditional probability P(Body Weight|Diabetes Mellitus, Type 1) is 0.01
# The conditional probability P(Obesity|Diabetes Mellitus, Type 1) is 0.01
# The conditional probability P(Proteinuria|Diabetes Mellitus, Type 1) is 0.01
# The conditional probability P(Albuminuria|Diabetes Mellitus, Type 1) is 0.04
# The conditional probability P(Virilism|Ovarian Neoplasms) is 0.01
# The conditional probability P(Body Weight|Kidney Diseases) is 0.01
# The conditional probability P(Proteinuria|Kidney Diseases) is 0.05
# The conditional probability P(Albuminuria|Kidney Diseases) is 0.01
# The conditional probability P(Colic|Kidney Diseases) is 0.01
# The conditional probability P(Obesity|Myocardial Ischemia) is 0.01
# The conditional probability P(Angina Pectoris|Myocardial Ischemia) is 0.04
# The conditional probability P(Chest Pain|Myocardial Ischemia) is 0.01
# The conditional probability P(Angina, Unstable|Myocardial Ischemia) is 0.02
# The conditional probability P(Acute Coronary Syndrome|Myocardial Ischemia) is 0.01
# The conditional probability P(Pain|Depressive Disorder) is 0.01
# The conditional probability P(Mental Retardation|Epilepsy) is 0.03
# The conditional probability P(Seizures|Epilepsy) is 0.07
# The conditional probability P(Myoclonus|Epilepsy) is 0.01
# The conditional probability P(Hemiplegia|Cerebral Infarction) is 0.02
# The conditional probability P(Muscle Weakness|Cerebral Infarction) is 0.02
# The conditional probability P(Aphasia|Cerebral Infarction) is 0.02
# The conditional probability P(Paresis|Cerebral Infarction) is 0.02
# The conditional probability P(Diarrhea|Acquired Immunodeficiency Syndrome) is 0.01
# The conditional probability P(Anoxia|Lung Diseases) is 0.01
# The conditional probability P(Dyspnea|Lung Diseases) is 0.01
# The conditional probability P(Hemoptysis|Lung Diseases) is 0.01
# The conditional probability P(Hallucinations|Parkinson Disease) is 0.01
# The conditional probability P(Tremor|Parkinson Disease) is 0.03
# The conditional probability P(Muscle Rigidity|Parkinson Disease) is 0.01
# The conditional probability P(Diarrhea|Bacterial Infections) is 0.02
# The conditional probability P(Fever|Bacterial Infections) is 0.02
# The conditional probability P(Jaundice|Liver Diseases) is 0.01
# The conditional probability P(Proteinuria|Lupus Erythematosus, Systemic) is 0.01
# The conditional probability P(Body Weight|Arteriosclerosis) is 0.01
# The conditional probability P(Obesity|Arteriosclerosis) is 0.02
# The conditional probability P(Angina Pectoris|Arrhythmias, Cardiac) is 0.01
# The conditional probability P(Syncope|Arrhythmias, Cardiac) is 0.02
# The conditional probability P(Pruritus|Skin Diseases) is 0.02
# The conditional probability P(Mental Retardation|Brain Diseases) is 0.02
# The conditional probability P(Seizures|Brain Diseases) is 0.03
# The conditional probability P(Headache|Brain Diseases) is 0.01
# The conditional probability P(Fatigue|Multiple Sclerosis) is 0.02
# The conditional probability P(Pain|Inflammation) is 0.03
# The conditional probability P(Obesity|Inflammation) is 0.03
# The conditional probability P(Edema|Inflammation) is 0.03
# The conditional probability P(Hyperalgesia|Inflammation) is 0.01
# The conditional probability P(Angina Pectoris|Heart Diseases) is 0.01
# The conditional probability P(Body Weight|Pregnancy Complications) is 0.01
# The conditional probability P(Obesity|Pregnancy Complications) is 0.02
# The conditional probability P(Birth Weight|Pregnancy Complications) is 0.03
# The conditional probability P(Memory Disorders|Cognition Disorders) is 0.07
# The conditional probability P(Learning Disorders|Cognition Disorders) is 0.01
# The conditional probability P(Amnesia|Cognition Disorders) is 0.02
# The conditional probability P(Language Disorders|Cognition Disorders) is 0.01
# The conditional probability P(Confusion|Cognition Disorders) is 0.02
# The conditional probability P(Hemiplegia|Stroke) is 0.02
# The conditional probability P(Muscle Weakness|Stroke) is 0.03
# The conditional probability P(Paresis|Stroke) is 0.03
# The conditional probability P(Purpura, Thrombocytopenic|Autoimmune Diseases) is 0.01
# The conditional probability P(Pain|Pancreatitis) is 0.02
# The conditional probability P(Abdominal Pain|Pancreatitis) is 0.02
# The conditional probability P(Pain|Bone Neoplasms) is 0.04
# The conditional probability P(Memory Disorders|Brain Injuries) is 0.02
# The conditional probability P(Coma|Brain Injuries) is 0.04
# The conditional probability P(Body Weight|Osteoporosis) is 0.02
# The conditional probability P(Fever|Sepsis) is 0.02
# The conditional probability P(Anoxia|Brain Ischemia) is 0.02
# The conditional probability P(Pain|Burns) is 0.02
# The conditional probability P(Body Weight|Diabetes Mellitus, Experimental) is 0.11
# The conditional probability P(Obesity|Diabetes Mellitus, Experimental) is 0.02
# The conditional probability P(Hemiplegia|Cerebrovascular Disorders) is 0.03
# The conditional probability P(Aphasia|Cerebrovascular Disorders) is 0.02
# The conditional probability P(Body Weight|Neoplasms, Experimental) is 0.02
# The conditional probability P(Anoxia|Ischemia) is 0.02
# The conditional probability P(Intermittent Claudication|Ischemia) is 0.02
# The conditional probability P(Seizures|Seizures) is 1.00
# The conditional probability P(Oliguria|Acute Kidney Injury) is 0.02
# The conditional probability P(Mental Retardation|Abnormalities, Multiple) is 0.15
# The conditional probability P(Deafness|Abnormalities, Multiple) is 0.02
# The conditional probability P(Mental Retardation|Mental Retardation) is 1.00
# The conditional probability P(Seizures|Mental Retardation) is 0.02
# The conditional probability P(Dyspepsia|Helicobacter Infections) is 0.09
# The conditional probability P(Hallucinations|Psychotic Disorders) is 0.04
# The conditional probability P(Cyanosis|Heart Defects, Congenital) is 0.04
# The conditional probability P(Pain|Spinal Cord Injuries) is 0.03
# The conditional probability P(Paralysis|Spinal Cord Injuries) is 0.02
# The conditional probability P(Paraplegia|Spinal Cord Injuries) is 0.08
# The conditional probability P(Quadriplegia|Spinal Cord Injuries) is 0.06
# The conditional probability P(Muscle Spasticity|Spinal Cord Injuries) is 0.02
# The conditional probability P(Urinary Bladder, Neurogenic|Spinal Cord Injuries) is 0.04
# The conditional probability P(Cough|Common Cold) is 0.02
# The conditional probability P(Pain|Angina Pectoris) is 0.02
# The conditional probability P(Angina Pectoris|Angina Pectoris) is 1.00
# The conditional probability P(Chest Pain|Angina Pectoris) is 0.02
# The conditional probability P(Angina, Unstable|Angina Pectoris) is 0.06
# The conditional probability P(Angina Pectoris, Variant|Angina Pectoris) is 0.03
# The conditional probability P(Dyspnea|Pulmonary Embolism) is 0.02
# The conditional probability P(Jaundice|Hepatitis) is 0.03
# The conditional probability P(Edema|Fetal Diseases) is 0.02
# The conditional probability P(Proteinuria|Glomerulonephritis) is 0.11
# The conditional probability P(Vision Disorders|Glaucoma) is 0.04
# The conditional probability P(Fever|Infection) is 0.03
# The conditional probability P(Anoxia|Hypertension, Pulmonary) is 0.09
# The conditional probability P(Birth Weight|Infant, Newborn, Diseases) is 0.04
# The conditional probability P(Intermittent Claudication|Arterial Occlusive Diseases) is 0.06
# The conditional probability P(Anoxia|Respiratory Insufficiency) is 0.06
# The conditional probability P(Hypercapnia|Respiratory Insufficiency) is 0.03
# The conditional probability P(Diarrhea|Gastrointestinal Diseases) is 0.03
# The conditional probability P(Birth Weight|Toxemia) is 0.03
# The conditional probability P(Proteinuria|Toxemia) is 0.04
# The conditional probability P(Birth Weight|Pre-Eclampsia) is 0.03
# The conditional probability P(Proteinuria|Pre-Eclampsia) is 0.04
# The conditional probability P(Body Weight|Hypothyroidism) is 0.03
# The conditional probability P(Dyspepsia|Peptic Ulcer) is 0.03
# The conditional probability P(Pain|Osteoarthritis) is 0.07
# The conditional probability P(Headache|Migraine Disorders) is 0.07
# The conditional probability P(Body Weight|Hyperlipidemias) is 0.04
# The conditional probability P(Obesity|Hyperlipidemias) is 0.06
# The conditional probability P(Pain|Arthritis) is 0.04
# The conditional probability P(Mental Retardation|Down Syndrome) is 0.04
# The conditional probability P(Learning Disorders|Attention Deficit Disorder with Hyperactivity) is 0.04
# The conditional probability P(Vision Disorders|Pituitary Neoplasms) is 0.03
# The conditional probability P(Pain|Muscular Diseases) is 0.06
# The conditional probability P(Muscular Atrophy|Muscular Diseases) is 0.03
# The conditional probability P(Pain|Peripheral Nervous System Diseases) is 0.07
# The conditional probability P(Paralysis|Peripheral Nervous System Diseases) is 0.03
# The conditional probability P(Neuralgia|Peripheral Nervous System Diseases) is 0.03
# The conditional probability P(Anoxia|Lung Diseases, Obstructive) is 0.05
# The conditional probability P(Dyspnea|Lung Diseases, Obstructive) is 0.03
# The conditional probability P(Dyspnea|Pulmonary Disease, Chronic Obstructive) is 0.06
# The conditional probability P(Body Weight|Hypercholesterolemia) is 0.03
# The conditional probability P(Pain|Anemia, Sickle Cell) is 0.06
# The conditional probability P(Cough|Gastroesophageal Reflux) is 0.03
# The conditional probability P(Heartburn|Gastroesophageal Reflux) is 0.05
# The conditional probability P(Body Weight|Mammary Neoplasms, Experimental) is 0.04
# The conditional probability P(Mental Retardation|Autistic Disorder) is 0.09
# The conditional probability P(Language Development Disorders|Autistic Disorder) is 0.05
# The conditional probability P(Pelvic Pain|Endometriosis) is 0.05
# The conditional probability P(Pain, Postoperative|Pain, Postoperative) is 1.00
# The conditional probability P(Diarrhea|Celiac Disease) is 0.03
# The conditional probability P(Syncope|Heart Block) is 0.04
# The conditional probability P(Deafness|Deafness) is 1.00
# The conditional probability P(Body Weight|Cardiomegaly) is 0.05
# The conditional probability P(Vision Disorders|Vision Disorders) is 1.00
# The conditional probability P(Blindness|Vision Disorders) is 0.03
# The conditional probability P(Proteinuria|Diabetic Nephropathies) is 0.10
# The conditional probability P(Albuminuria|Diabetic Nephropathies) is 0.21
# The conditional probability P(Headache|Headache) is 0.99
# The conditional probability P(Vision Disorders|Retinal Diseases) is 0.06
# The conditional probability P(Pruritus|Dermatitis, Atopic) is 0.04
# The conditional probability P(Mental Retardation|Child Behavior Disorders) is 0.05
# The conditional probability P(Learning Disorders|Child Behavior Disorders) is 0.08
# The conditional probability P(Coma|Craniocerebral Trauma) is 0.04
# The conditional probability P(Dyspepsia|Gastritis) is 0.04
# The conditional probability P(Body Weight|Liver Neoplasms, Experimental) is 0.04
# The conditional probability P(Proteinuria|Nephrotic Syndrome) is 0.15
# The conditional probability P(Diarrhea|Escherichia coli Infections) is 0.11
# The conditional probability P(Seizures|Substance Withdrawal Syndrome) is 0.04
# The conditional probability P(Obesity|Metabolic Syndrome X) is 0.25
# The conditional probability P(Birth Weight|Infant, Premature, Diseases) is 0.06
# The conditional probability P(Apnea|Infant, Premature, Diseases) is 0.05
# The conditional probability P(Pain|Joint Diseases) is 0.06
# The conditional probability P(Back Pain|Spinal Diseases) is 0.07
# The conditional probability P(Low Back Pain|Spinal Diseases) is 0.04
# The conditional probability P(Obesity|Hyperglycemia) is 0.06
# The conditional probability P(Obesity|Sleep Apnea Syndromes) is 0.07
# The conditional probability P(Anoxia|Sleep Apnea Syndromes) is 0.06
# The conditional probability P(Snoring|Sleep Apnea Syndromes) is 0.10
# The conditional probability P(Obesity|Fatty Liver) is 0.14
# The conditional probability P(Mental Retardation|Chromosome Aberrations) is 0.08
# The conditional probability P(Abdominal Pain|Appendicitis) is 0.06
# The conditional probability P(Abdomen, Acute|Appendicitis) is 0.05
# The conditional probability P(Pain|Athletic Injuries) is 0.06
# The conditional probability P(Anoxia|Pulmonary Edema) is 0.04
# The conditional probability P(Diarrhea|Colitis) is 0.07
# The conditional probability P(Memory Disorders|Memory Disorders) is 1.00
# The conditional probability P(Learning Disorders|Memory Disorders) is 0.06
# The conditional probability P(Body Weight|Growth Disorders) is 0.09
# The conditional probability P(Mental Retardation|Growth Disorders) is 0.06
# The conditional probability P(Hearing Loss, Sensorineural|Hearing Loss, Sensorineural) is 0.99
# The conditional probability P(Mental Retardation|Cerebral Palsy) is 0.05
# The conditional probability P(Hemiplegia|Cerebral Palsy) is 0.05
# The conditional probability P(Muscle Spasticity|Cerebral Palsy) is 0.10
# The conditional probability P(Body Weight|Nutrition Disorders) is 0.15
# The conditional probability P(Sleep Disorders|Sleep Disorders) is 1.00
# The conditional probability P(Body Weight|Anorexia Nervosa) is 0.16
# The conditional probability P(Bulimia|Anorexia Nervosa) is 0.18
# The conditional probability P(Pain|Diabetic Neuropathies) is 0.07
# The conditional probability P(Urinary Incontinence|Urinary Incontinence) is 1.00
# The conditional probability P(Urinary Incontinence, Stress|Urinary Incontinence) is 0.09
# The conditional probability P(Urinary Bladder, Neurogenic|Urinary Incontinence) is 0.06
# The conditional probability P(Diarrhea|Intestinal Diseases) is 0.05
# The conditional probability P(Fever|Neutropenia) is 0.19
# The conditional probability P(Low Back Pain|Low Back Pain) is 1.00
# The conditional probability P(Intermittent Claudication|Peripheral Arterial Disease) is 0.08
# The conditional probability P(Obesity|Polycystic Ovary Syndrome) is 0.14
# The conditional probability P(Hirsutism|Polycystic Ovary Syndrome) is 0.08
# The conditional probability P(Paralysis|Paralysis) is 1.00
# The conditional probability P(Intermittent Claudication|Peripheral Vascular Diseases) is 0.08
# The conditional probability P(Back Pain|Back Pain) is 1.00
# The conditional probability P(Sciatica|Back Pain) is 0.07
# The conditional probability P(Memory Disorders|Learning Disorders) is 0.06
# The conditional probability P(Learning Disorders|Learning Disorders) is 1.00
# The conditional probability P(Dyslexia|Learning Disorders) is 0.07
# The conditional probability P(Body Weight|Fetal Growth Retardation) is 0.06
# The conditional probability P(Birth Weight|Fetal Growth Retardation) is 0.15
# The conditional probability P(Deafness|Hearing Disorders) is 0.06
# The conditional probability P(Hearing Disorders|Hearing Disorders) is 1.00
# The conditional probability P(Back Pain|Intervertebral Disk Displacement) is 0.07
# The conditional probability P(Low Back Pain|Intervertebral Disk Displacement) is 0.08
# The conditional probability P(Sciatica|Intervertebral Disk Displacement) is 0.09
# The conditional probability P(Mental Retardation|Developmental Disabilities) is 0.11
# The conditional probability P(Facial Pain|Temporomandibular Joint Disorders) is 0.17
# The conditional probability P(Vision Disorders|Glaucoma, Open-Angle) is 0.10
# The conditional probability P(Obesity|Sleep Apnea, Obstructive) is 0.09
# The conditional probability P(Snoring|Sleep Apnea, Obstructive) is 0.10
# The conditional probability P(Blindness|Blindness) is 1.00
# The conditional probability P(Seizures|Epilepsy, Temporal Lobe) is 0.07
# The conditional probability P(Birth Weight|Respiratory Distress Syndrome, Newborn) is 0.06
# The conditional probability P(Psychophysiologic Disorders|Neurotic Disorders) is 0.08
# The conditional probability P(Diarrhea|Gastroenteritis) is 0.10
# The conditional probability P(Proteinuria|Proteinuria) is 1.00
# The conditional probability P(Albuminuria|Proteinuria) is 0.10
# The conditional probability P(Muscular Atrophy|Neuromuscular Diseases) is 0.06
# The conditional probability P(Body Weight|Eating Disorders) is 0.12
# The conditional probability P(Obesity|Eating Disorders) is 0.09
# The conditional probability P(Bulimia|Eating Disorders) is 0.09
# The conditional probability P(Anorexia|Eating Disorders) is 0.07
# The conditional probability P(Hyperphagia|Eating Disorders) is 0.12
# The conditional probability P(Birth Weight|Pregnancy in Diabetics) is 0.12
# The conditional probability P(Cough|Cough) is 1.00
# The conditional probability P(Neuralgia|Herpes Zoster) is 0.13
# The conditional probability P(Urinary Incontinence|Urination Disorders) is 0.09
# The conditional probability P(Facial Paralysis|Facial Paralysis) is 1.00
# The conditional probability P(Amblyopia|Strabismus) is 0.21
# The conditional probability P(Coma|Coma) is 1.00
# The conditional probability P(Angina Pectoris|Angina, Unstable) is 0.18
# The conditional probability P(Angina, Unstable|Angina, Unstable) is 1.00
# The conditional probability P(Syncope|Syncope) is 1.00
# The conditional probability P(Dizziness|Dizziness) is 1.00
# The conditional probability P(Vertigo|Dizziness) is 0.80
# The conditional probability P(Paraplegia|Paraplegia) is 1.00
# The conditional probability P(Quadriplegia|Paraplegia) is 0.07
# The conditional probability P(Dyspnea|Dyspnea) is 1.00
# The conditional probability P(Ophthalmoplegia|Ophthalmoplegia) is 1.00
# The conditional probability P(Urinary Incontinence|Urinary Bladder Diseases) is 0.07
# The conditional probability P(Pain|Foot Diseases) is 0.07
# The conditional probability P(Aphasia|Aphasia) is 1.00
# The conditional probability P(Aphasia, Broca|Aphasia) is 0.12
# The conditional probability P(Aphasia, Wernicke|Aphasia) is 0.09
# The conditional probability P(Pain|Osteoarthritis, Knee) is 0.14
# The conditional probability P(Dystonia|Dystonia) is 1.00
# The conditional probability P(Speech Disorders|Speech Disorders) is 1.00
# The conditional probability P(Language Disorders|Speech Disorders) is 0.11
# The conditional probability P(Psychophysiologic Disorders|Somatoform Disorders) is 0.19
# The conditional probability P(Hemiplegia|Hemiplegia) is 1.00
# The conditional probability P(Pain|Fibromyalgia) is 0.24
# The conditional probability P(Dyslexia|Dyslexia) is 1.00
# The conditional probability P(Muscular Atrophy|Muscular Atrophy) is 1.00
# The conditional probability P(Hearing Loss, Sensorineural|Hearing Loss) is 0.08
# The conditional probability P(Hearing Loss|Hearing Loss) is 1.00
# The conditional probability P(Hearing Loss, Conductive|Hearing Loss) is 0.10
# The conditional probability P(Pain|Neuralgia) is 0.08
# The conditional probability P(Neuralgia|Neuralgia) is 1.00
# The conditional probability P(Hyperalgesia|Neuralgia) is 0.11
# The conditional probability P(Body Weight|Protein-Energy Malnutrition) is 0.17
# The conditional probability P(Vision Disorders|Optic Nerve Diseases) is 0.14
# The conditional probability P(Mental Retardation|Phenylketonurias) is 0.08
# The conditional probability P(Albuminuria|Albuminuria) is 1.00
# The conditional probability P(Diarrhea|Malabsorption Syndromes) is 0.10
# The conditional probability P(Seizures|Status Epilepticus) is 0.09
# The conditional probability P(Dizziness|Vertigo) is 1.00
# The conditional probability P(Vertigo|Vertigo) is 1.00
# The conditional probability P(Proteinuria|Glomerulonephritis, IGA) is 0.15
# The conditional probability P(Jaundice|Jaundice) is 1.00
# The conditional probability P(Diarrhea|Enterocolitis, Pseudomembranous) is 0.15
# The conditional probability P(Purpura, Thrombocytopenic|Purpura, Thrombocytopenic) is 1.00
# The conditional probability P(Tremor|Tremor) is 1.00
# The conditional probability P(Pain, Intractable|Pain, Intractable) is 1.00
# The conditional probability P(Pruritus|Pruritus) is 1.00
# The conditional probability P(Hallucinations|Hallucinations) is 1.00
# The conditional probability P(Amnesia|Amnesia) is 1.00
# The conditional probability P(Pain|Hyperalgesia) is 0.24
# The conditional probability P(Hyperalgesia|Hyperalgesia) is 1.00
# The conditional probability P(Amblyopia|Amblyopia) is 1.00
# The conditional probability P(Acute Coronary Syndrome|Acute Coronary Syndrome) is 1.00
# The conditional probability P(Weight Loss|Obesity, Morbid) is 0.24
# The conditional probability P(Obesity, Morbid|Obesity, Morbid) is 1.00
# The conditional probability P(Obesity|Hyperinsulinism) is 0.18
# The conditional probability P(Speech Disorders|Language Disorders) is 0.16
# The conditional probability P(Language Disorders|Language Disorders) is 1.00
# The conditional probability P(Language Development Disorders|Language Disorders) is 0.11
# The conditional probability P(Cardiac Output, Low|Cardiac Output, Low) is 1.00
# The conditional probability P(Muscle Weakness|Muscle Weakness) is 1.00
# The conditional probability P(Paresis|Muscle Weakness) is 0.49
# The conditional probability P(Purpura, Thrombocytopenic, Idiopathic|Purpura, Thrombocytopenic, Idiopathic) is 1.00
# The conditional probability P(Dizziness|Meniere Disease) is 0.17
# The conditional probability P(Vertigo|Meniere Disease) is 0.16
# The conditional probability P(Urinary Incontinence|Urinary Bladder, Neurogenic) is 0.14
# The conditional probability P(Urinary Bladder, Neurogenic|Urinary Bladder, Neurogenic) is 1.00
# The conditional probability P(Perceptual Disorders|Perceptual Disorders) is 1.00
# The conditional probability P(Purpura, Thrombotic Thrombocytopenic|Hemolytic-Uremic Syndrome) is 0.14
# The conditional probability P(Facial Pain|Temporomandibular Joint Dysfunction Syndrome) is 0.11
# The conditional probability P(Intermittent Claudication|Intermittent Claudication) is 1.00
# The conditional probability P(Tinnitus|Tinnitus) is 1.00
# The conditional probability P(Mental Retardation|Fragile X Syndrome) is 0.18
# The conditional probability P(Urinary Incontinence|Fecal Incontinence) is 0.16
# The conditional probability P(Constipation|Fecal Incontinence) is 0.14
# The conditional probability P(Myoclonus|Myoclonus) is 1.00
# The conditional probability P(Delirium|Delirium) is 1.00
# The conditional probability P(Dizziness|Nystagmus, Pathologic) is 0.11
# The conditional probability P(Urinary Incontinence, Stress|Urinary Incontinence, Stress) is 1.00
# The conditional probability P(Apnea|Apnea) is 1.00
# The conditional probability P(Diarrhea|Campylobacter Infections) is 0.13
# The conditional probability P(Muscle Spasticity|Muscle Spasticity) is 1.00
# The conditional probability P(Hearing Loss, Noise-Induced|Hearing Loss, Noise-Induced) is 1.00
# The conditional probability P(Purpura, Thrombotic Thrombocytopenic|Purpura, Thrombotic Thrombocytopenic) is 1.00
# The conditional probability P(Quadriplegia|Quadriplegia) is 1.00
# The conditional probability P(Voice Disorders|Voice Disorders) is 1.00
# The conditional probability P(Purpura, Schoenlein-Henoch|Purpura, Schoenlein-Henoch) is 1.00
# The conditional probability P(Language Development Disorders|Language Development Disorders) is 1.00
# The conditional probability P(Body Weight|Starvation) is 0.13
# The conditional probability P(Mental Retardation|Sex Chromosome Aberrations) is 0.16
# The conditional probability P(Hirsutism|Hypertrichosis) is 0.75
# The conditional probability P(Proteinuria|Glomerulosclerosis, Focal Segmental) is 0.20
# The conditional probability P(Ataxia|Ataxia) is 1.00
# The conditional probability P(Angina Pectoris|Coronary Vasospasm) is 0.19
# The conditional probability P(Angina Pectoris, Variant|Coronary Vasospasm) is 0.18
# The conditional probability P(Obesity|Glucose Intolerance) is 0.16
# The conditional probability P(Facial Pain|Facial Pain) is 1.00
# The conditional probability P(Hemoptysis|Hemoptysis) is 1.00
# The conditional probability P(Body Weight|Protein Deficiency) is 0.22
# The conditional probability P(Diarrhea|Cholera) is 0.15
# The conditional probability P(Spasm|Spasm) is 1.00
# The conditional probability P(Cerebellar Ataxia|Cerebellar Ataxia) is 1.00
# The conditional probability P(Chorea|Chorea) is 1.00
# The conditional probability P(Athetosis|Chorea) is 0.17
# The conditional probability P(Vocal Cord Paralysis|Vocal Cord Paralysis) is 1.00
# The conditional probability P(Purpura|Purpura) is 1.00
# The conditional probability P(Stuttering|Stuttering) is 1.00
# The conditional probability P(Back Pain|Sciatica) is 0.19
# The conditional probability P(Sciatica|Sciatica) is 1.00
# The conditional probability P(Dizziness|Labyrinth Diseases) is 0.16
# The conditional probability P(Color Vision Defects|Color Vision Defects) is 1.00
# The conditional probability P(Diarrhea|Rotavirus Infections) is 0.28
# The conditional probability P(Hyperventilation|Hyperventilation) is 1.00
# The conditional probability P(Hypergammaglobulinemia|Hypergammaglobulinemia) is 1.00
# The conditional probability P(Psychomotor Disorders|Psychomotor Disorders) is 1.00
# The conditional probability P(Hyperkinesis|Hyperkinesis) is 1.00
# The conditional probability P(Hirsutism|Hirsutism) is 1.00
# The conditional probability P(Diarrhea|Cryptosporidiosis) is 0.22
# The conditional probability P(Sleep Deprivation|Sleep Deprivation) is 1.00
# The conditional probability P(Dizziness|Vestibular Diseases) is 0.21
# The conditional probability P(Sensation Disorders|Sensation Disorders) is 1.00
# The conditional probability P(Neck Pain|Neck Pain) is 1.00
# The conditional probability P(Olfaction Disorders|Olfaction Disorders) is 1.00
# The conditional probability P(Torticollis|Torticollis) is 1.00
# The conditional probability P(Anoxia|Altitude Sickness) is 0.41
# The conditional probability P(Obesity|Insulin Resistance) is 0.26
# The conditional probability P(Paresthesia|Paresthesia) is 1.00
# The conditional probability P(Arthralgia|Arthralgia) is 1.00
# The conditional probability P(Fetal Hypoxia|Fetal Hypoxia) is 1.00
# The conditional probability P(Muscle Weakness|Paresis) is 1.00
# The conditional probability P(Paresis|Paresis) is 1.00
# The conditional probability P(Mental Retardation|Microcephaly) is 0.30
# The conditional probability P(Psychomotor Agitation|Psychomotor Agitation) is 1.00
# The conditional probability P(Dysmenorrhea|Dysmenorrhea) is 1.00
# The conditional probability P(Gait Disorders, Neurologic|Gait Disorders, Neurologic) is 1.00
# The conditional probability P(Apraxias|Apraxias) is 1.00
# The conditional probability P(Angina Pectoris|Angina Pectoris, Variant) is 0.31
# The conditional probability P(Angina Pectoris, Variant|Angina Pectoris, Variant) is 1.00
# The conditional probability P(Urinary Bladder, Overactive|Urinary Bladder, Overactive) is 1.00
# The conditional probability P(Diplopia|Diplopia) is 1.00
# The conditional probability P(Confusion|Confusion) is 1.00
# The conditional probability P(Supranuclear Palsy, Progressive|Supranuclear Palsy, Progressive) is 1.00
# The conditional probability P(Hearing Loss, Sudden|Hearing Loss, Sudden) is 1.00
# The conditional probability P(Hemianopsia|Hemianopsia) is 1.00
# The conditional probability P(Hearing Loss|Hearing Loss, Conductive) is 0.30
# The conditional probability P(Hearing Loss, Conductive|Hearing Loss, Conductive) is 1.00
# The conditional probability P(Shoulder Pain|Shoulder Pain) is 1.00
# The conditional probability P(Agnosia|Agnosia) is 1.00
# The conditional probability P(Unconsciousness|Unconsciousness) is 1.00
# The conditional probability P(Catatonia|Catatonia) is 1.00
# The conditional probability P(Hydrops Fetalis|Hydrops Fetalis) is 1.00
# The conditional probability P(Cerebrospinal Fluid Rhinorrhea|Cerebrospinal Fluid Rhinorrhea) is 1.00
# The conditional probability P(Syncope, Vasovagal|Syncope, Vasovagal) is 1.00
# The conditional probability P(Jaundice, Obstructive|Jaundice, Obstructive) is 1.00
# The conditional probability P(Horner Syndrome|Horner Syndrome) is 1.00
# The conditional probability P(Toothache|Toothache) is 1.00
# The conditional probability P(Muscle Hypotonia|Muscle Hypotonia) is 1.00
# The conditional probability P(Dystonia|Dystonic Disorders) is 1.00
# The conditional probability P(Catalepsy|Catalepsy) is 1.00
# The conditional probability P(Tetany|Tetany) is 1.00
# The conditional probability P(Consciousness Disorders|Consciousness Disorders) is 1.00
# The conditional probability P(Dysarthria|Dysarthria) is 1.00
# The conditional probability P(Respiratory Paralysis|Respiratory Paralysis) is 1.00
# The conditional probability P(Aphasia, Broca|Aphasia, Broca) is 1.00
# The conditional probability P(Scotoma|Scotoma) is 1.00
# The conditional probability P(Muscle Cramp|Muscle Cramp) is 1.00
# The conditional probability P(Articulation Disorders|Articulation Disorders) is 1.00
# The conditional probability P(Vision, Low|Vision, Low) is 1.00
# The conditional probability P(Hearing Loss, Bilateral|Hearing Loss, Bilateral) is 1.00
# The conditional probability P(Muscle Rigidity|Muscle Rigidity) is 1.00
# The conditional probability P(Hypesthesia|Hypesthesia) is 1.00
# The conditional probability P(Hyperemesis Gravidarum|Hyperemesis Gravidarum) is 1.00
# The conditional probability P(Taste Disorders|Taste Disorders) is 1.00
# The conditional probability P(Persistent Vegetative State|Persistent Vegetative State) is 1.00
# The conditional probability P(Gastroparesis|Gastroparesis) is 1.00
# The conditional probability P(Reflex, Abnormal|Reflex, Abnormal) is 1.00
# The conditional probability P(Decerebrate State|Decerebrate State) is 1.00
# The conditional probability P(Auditory Perceptual Disorders|Auditory Perceptual Disorders) is 1.00
# The conditional probability P(Phantom Limb|Phantom Limb) is 1.00
# The conditional probability P(Hematemesis|Hematemesis) is 1.00
# The conditional probability P(Hypoventilation|Hypoventilation) is 1.00
# The conditional probability P(Communication Disorders|Communication Disorders) is 1.00
# The conditional probability P(Oral Hemorrhage|Oral Hemorrhage) is 1.00
# The conditional probability P(Myotonia|Myotonia) is 1.00
# The conditional probability P(Dyskinesias|Dyskinesias) is 1.00
# The conditional probability P(Polyuria|Polyuria) is 1.00
# The conditional probability P(Fetal Macrosomia|Fetal Macrosomia) is 1.00
# The conditional probability P(Chorea|Athetosis) is 0.63
# The conditional probability P(Athetosis|Athetosis) is 1.00
# The conditional probability P(Presbycusis|Presbycusis) is 1.00
# The conditional probability P(Tinea Pedis|Tinea Pedis) is 1.00
# The conditional probability P(Dyslexia, Acquired|Dyslexia, Acquired) is 1.00
# The conditional probability P(Mutism|Mutism) is 1.00
# The conditional probability P(Hoarseness|Hoarseness) is 1.00
# The conditional probability P(Hypokinesia|Hypokinesia) is 1.00
# The conditional probability P(Amnesia, Retrograde|Amnesia, Retrograde) is 1.00
# The conditional probability P(Somatosensory Disorders|Somatosensory Disorders) is 1.00
# The conditional probability P(Postoperative Nausea and Vomiting|Postoperative Nausea and Vomiting) is 1.00
# The conditional probability P(Anomia|Anomia) is 1.00
# The conditional probability P(Agraphia|Agraphia) is 1.00
# The conditional probability P(Trismus|Trismus) is 1.00
# The conditional probability P(Cerebrospinal Fluid Otorrhea|Cerebrospinal Fluid Otorrhea) is 1.00
# The conditional probability P(Akathisia, Drug-Induced|Akathisia, Drug-Induced) is 1.00
# The conditional probability P(Aphasia, Wernicke|Aphasia, Wernicke) is 1.00
# The conditional probability P(Hemifacial Spasm|Hemifacial Spasm) is 1.00
# The conditional probability P(Muscle Hypertonia|Muscle Hypertonia) is 1.00
# The conditional probability P(Encopresis|Encopresis) is 1.00
# The conditional probability P(Hyperesthesia|Hyperesthesia) is 1.00
# The conditional probability P(Hearing Loss, High-Frequency|Hearing Loss, High-Frequency) is 1.00
# The conditional probability P(Pupil Disorders|Pupil Disorders) is 1.00
# The conditional probability P(Eye Hemorrhage|Eye Hemorrhage) is 1.00
# The conditional probability P(Ecchymosis|Ecchymosis) is 1.00
# The conditional probability P(Hemoglobinuria|Hemoglobinuria) is 1.00
# The conditional probability P(Oliguria|Oliguria) is 1.00
# The conditional probability P(Mouth Breathing|Mouth Breathing) is 1.00
# The conditional probability P(Ophthalmoplegia, Chronic Progressive External|Ophthalmoplegia, Chronic Progressive External) is 1.00

# %%
# Function to validate the probabilities
def validate_probabilities(df):
    invalid_probs = df[(df['P(Symptom|Disease)'] < 0) | (df['P(Symptom|Disease)'] > 1)]
    if not invalid_probs.empty:
        print("Invalid probabilities found:")
        print(invalid_probs)
    else:
        print("All probabilities are within the valid range [0, 1].")

    for disease in df['MeSH Disease Term'].unique():
        total_prob = df[df['MeSH Disease Term'] == disease]['P(Symptom|Disease)'].sum()
        if total_prob > 1:
            print(f"Warning: Sum of probabilities for disease {disease} exceeds 1. Total: {total_prob}")

# Compute and print the conditional probabilities for all disease-symptom pairs
results = []
for disease in diseases:
    for symptom in symptoms:
        conditional_prob = compute_conditional_probability(disease, symptom, merged_data)
        if conditional_prob is not None:
            results.append({'MeSH Disease Term': disease, 'MeSH Symptom Term': symptom, 'P(Symptom|Disease)': conditional_prob})

results_df = pd.DataFrame(results)

# Validate the probabilities
validate_probabilities(results_df)

# Print the valid results
print(results_df)
# Out:
# All probabilities are within the valid range [0, 1].
#   MeSH Disease Term MeSH Symptom Term  P(Symptom|Disease)
# 0           Obesity           Obesity            0.994512

# %%
import pandas as pd

# Assuming the previous data cleaning and merging steps are done and we have `merged_data` ready

# Function to compute the conditional probability for a specific pair
def compute_conditional_probability(disease, symptom, df):
    subset = df[(df['MeSH Disease Term'] == disease) & (df['MeSH Symptom Term'] == symptom)]
    if not subset.empty:
        cooccurrence = subset['PubMed occurrence'].values[0]
        disease_occurrence = subset['PubMed occurrence_Disease'].values[0]
        return cooccurrence / disease_occurrence
    else:
        return None

# Function to calculate the likelihood of a disease given a list of symptoms
def calculate_disease_likelihood(symptoms, diseases, df):
    likelihoods = {disease: 1.0 for disease in diseases}
    for disease in diseases:
        for symptom in symptoms:
            prob = compute_conditional_probability(disease, symptom, df)
            if prob is not None:
                likelihoods[disease] *= prob
            else:
                likelihoods[disease] *= 0.01  # Small value for missing probabilities
    return likelihoods

# Function to get the most likely disease based on symptoms
def get_most_likely_disease(symptoms, diseases, df):
    likelihoods = calculate_disease_likelihood(symptoms, diseases, df)
    most_likely_disease = max(likelihoods, key=likelihoods.get)
    return most_likely_disease, likelihoods[most_likely_disease]

# Interface for user input
def main_interface():
    print("Welcome to the Disease Prediction Bot!")
    print("Please enter the symptoms you are experiencing, separated by commas.")
    user_input = input("Symptoms: ")
    observed_symptoms = [symptom.strip().lower() for symptom in user_input.split(",")]

    most_likely_disease, likelihood = get_most_likely_disease(observed_symptoms, diseases, merged_data)
    print(f"The most likely disease based on your symptoms is: {most_likely_disease}")
    print(f"Likelihood: {likelihood:.2f}")

# Get the list of diseases and symptoms
diseases = data1['MeSH Disease Term'].unique()
symptoms = data2['MeSH Symptom Term'].unique()

main_interface()
# Out:
# Welcome to the Disease Prediction Bot!
# Please enter the symptoms you are experiencing, separated by commas.
# Symptoms: pain
# The most likely disease based on your symptoms is: Breast Neoplasms
# Likelihood: 0.01

# %%
import pandas as pd
import networkx as nx
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD

# Load the datasets
path1 = '/content/drive/My Drive/data1.txt'
path2 = '/content/drive/My Drive/data2.txt'
path3 = '/content/drive/My Drive/data3.txt'

data1 = pd.read_csv(path1, delimiter='\t')
data2 = pd.read_csv(path2, delimiter='\t')
data3 = pd.read_csv(path3, delimiter='\t')

# Constructing the Bayesian Network
directed_graph = nx.DiGraph()

# Collect potential edges
potential_edges = []

for index, row in data3.iterrows():
    disease = row['MeSH Disease Term'].strip().lower()
    symptom = row['MeSH Symptom Term'].strip().lower()
    if disease != symptom:
        potential_edges.append((disease, symptom))

# Add edges and check for DAG
for edge in potential_edges:
    directed_graph.add_edge(*edge)
    if not nx.is_directed_acyclic_graph(directed_graph):
        directed_graph.remove_edge(*edge)

bn_model = BayesianNetwork(directed_graph.edges())

# Adding CPDs to the Bayesian Network based on its structure
for node in bn_model.nodes():
    parents = list(directed_graph.predecessors(node))
    variable_card = 2  # Assuming binary variables

    if parents:
        # Setup a basic CPD for nodes with parents
        evidence_card = [2] * len(parents)
        values = [[0.8, 0.2], [0.2, 0.8]]  # Simplified example
        cpd = TabularCPD(variable=node, variable_card=variable_card, values=values,
                         evidence=parents, evidence_card=evidence_card)
    else:
        # Setup a default CPD for nodes without parents
        cpd = TabularCPD(variable=node, variable_card=variable_card, values=[[0.5], [0.5]])

    bn_model.add_cpds(cpd)

# Check the model's validity after all CPDs have been added
if bn_model.check_model():
    print("The Bayesian network is correctly defined and valid.")
else:
    print("There was a problem with the network definition or CPDs.")

print("Nodes in the Bayesian Network:", bn_model.nodes())
print("Edges in the Bayesian Network:", bn_model.edges())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-86f65f56ee21> in <cell line: 36>()
#      42         evidence_card = [2] * len(parents)
#      43         values = [[0.8, 0.2], [0.2, 0.8]]  # Simplified example
# ---> 44         cpd = TabularCPD(variable=node, variable_card=variable_card, values=values,
#      45                          evidence=parents, evidence_card=evidence_card)
#      46     else:
#
# /usr/local/lib/python3.10/dist-packages/pgmpy/factors/discrete/CPD.py in __init__(self, variable, variable_card, values, evidence, evidence_card, state_names)
#     140             expected_cpd_shape = (variable_card, np.prod(evidence_card))
#     141         if values.shape != expected_cpd_shape:
# --> 142             raise ValueError(
#     143                 f"values must be of shape {expected_cpd_shape}. Got shape: {values.shape}"
#     144             )
#
# ValueError: values must be of shape (2, 0). Got shape: (2, 2)

# %%
import pandas as pd
import numpy as np
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination
import networkx as nx

# Assuming the data has been loaded into data1, data2, and data3 DataFrames
# Loading the datasets
path1 = '/content/drive/My Drive/data1.txt'
path2 = '/content/drive/My Drive/data2.txt'
path3 = '/content/drive/My Drive/data3.txt'

data1 = pd.read_csv(path1, delimiter='\t')
data2 = pd.read_csv(path2, delimiter='\t')
data3 = pd.read_csv(path3, delimiter='\t')

# Constructing the Bayesian Network
directed_graph = nx.DiGraph()

for index, row in data3.iterrows():
    disease = row['MeSH Disease Term'].strip().lower()
    symptom = row['MeSH Symptom Term'].strip().lower()
    if disease != symptom:
        if not directed_graph.has_edge(disease, symptom):
            directed_graph.add_edge(disease, symptom)
            if not nx.is_directed_acyclic_graph(directed_graph):
                directed_graph.remove_edge(disease, symptom)

bn_model = BayesianNetwork(directed_graph.edges())

# Adding CPDs to the Bayesian Network based on its structure
for node in bn_model.nodes():
    parents = list(directed_graph.predecessors(node))
    variable_card = 2  # Assuming binary variables

    if parents:
        # Setup a basic CPD for nodes with parents
        evidence_card = [2] * len(parents)
        values = [[0.8, 0.2], [0.2, 0.8]]  # Assuming binary states and one parent for simplicity
        cpd = TabularCPD(variable=node, variable_card=variable_card, values=values,
                         evidence=parents, evidence_card=evidence_card)
    else:
        # Setup a default CPD for nodes without parents
        cpd = TabularCPD(variable=node, variable_card=variable_card, values=[[0.5], [0.5]])

    bn_model.add_cpds(cpd)

# Check the model's validity after all CPDs have been added
if bn_model.check_model():
    print("The Bayesian network is correctly defined and valid.")
else:
    print("There was a problem with the network definition or CPDs.")

print("Nodes in the Bayesian Network:", bn_model.nodes())
print("Edges in the Bayesian Network:", bn_model.edges())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c3620f2381c0> in <cell line: 21>()
#      25         if not directed_graph.has_edge(disease, symptom):
#      26             directed_graph.add_edge(disease, symptom)
# ---> 27             if not nx.is_directed_acyclic_graph(directed_graph):
#      28                 directed_graph.remove_edge(disease, symptom)
#      29
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/decorators.py in argmap_is_directed_acyclic_graph_1(G, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/backends.py in __call__(self, backend, *args, **kwargs)
#     631         if not backends:
#     632             # Fast path if no backends are installed
# --> 633             return self.orig_func(*args, **kwargs)
#     634
#     635         # Use `backend_name` in this function instead of `backend`
#
# /usr/local/lib/python3.10/dist-packages/networkx/algorithms/dag.py in is_directed_acyclic_graph(G)
#     161     topological_sort
#     162     """
# --> 163     return G.is_directed() and not has_cycle(G)
#     164
#     165
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/decorators.py in argmap_has_cycle_5(G, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/backends.py in __call__(self, backend, *args, **kwargs)
#     631         if not backends:
#     632             # Fast path if no backends are installed
# --> 633             return self.orig_func(*args, **kwargs)
#     634
#     635         # Use `backend_name` in this function instead of `backend`
#
# /usr/local/lib/python3.10/dist-packages/networkx/algorithms/dag.py in has_cycle(G)
#     116     try:
#     117         # Feed the entire iterator into a zero-length deque.
# --> 118         deque(topological_sort(G), maxlen=0)
#     119     except nx.NetworkXUnfeasible:
#     120         return True
#
# /usr/local/lib/python3.10/dist-packages/networkx/algorithms/dag.py in topological_sort(G)
#     307        *Introduction to Algorithms - A Creative Approach.* Addison-Wesley.
#     308     """
# --> 309     for generation in nx.topological_generations(G):
#     310         yield from generation
#     311
#
# /usr/local/lib/python3.10/dist-packages/networkx/algorithms/dag.py in topological_generations(G)
#     228             for child in G.neighbors(node):
#     229                 try:
# --> 230                     indegree_map[child] -= len(G[node][child]) if multigraph else 1
#     231                 except KeyError as err:
#     232                     raise RuntimeError("Graph changed during iteration") from err
#
# KeyboardInterrupt:

# %%
network_structure = []
directed_graph = nx.DiGraph()

for index, row in data3.iterrows():
    disease = row['MeSH Disease Term'].strip().lower()
    symptom = row['MeSH Symptom Term'].strip().lower()
    if disease != symptom:
        if not directed_graph.has_edge(disease, symptom):
            directed_graph.add_edge(disease, symptom)
            if not nx.is_directed_acyclic_graph(directed_graph):
                directed_graph.remove_edge(disease, symptom)

bn_model = BayesianNetwork(directed_graph.edges())

# Incrementally add CPDs and check the model
for node in bn_model.nodes():
    parents = list(directed_graph.predecessors(node))
    if parents:
        # Simplified CPD for demonstration: Binary states, reduced complexity
        values = [[0.8, 0.2], [0.2, 0.8]]  # Assuming only one parent for simplicity
        cpd = TabularCPD(variable=node, variable_card=2, values=values, evidence=parents, evidence_card=[2])
    else:
        # Nodes without parents: Assume equal probability for states
        cpd = TabularCPD(variable=node, variable_card=2, values=[[0.5], [0.5]])
    bn_model.add_cpds(cpd)

    # Check model incrementally to catch issues early
    if not bn_model.check_model():
        print(f"Problem found after adding CPD for {node}.")
        break

if bn_model.check_model():
    print("The Bayesian network is correctly defined and valid.")
else:
    print("There was a problem with the network definition or CPDs.")

print("Nodes in the Bayesian Network:", bn_model.nodes())
print("Edges in the Bayesian Network:", bn_model.edges())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-be2fd8b5be31> in <cell line: 16>()
#      26
#      27     # Check model incrementally to catch issues early
# ---> 28     if not bn_model.check_model():
#      29         print(f"Problem found after adding CPD for {node}.")
#      30         break
#
# /usr/local/lib/python3.10/dist-packages/pgmpy/models/BayesianNetwork.py in check_model(self)
#     407             # Check if a CPD is associated with every node.
#     408             if cpd is None:
# --> 409                 raise ValueError(f"No CPD associated with {node}")
#     410
#     411             # Check if the CPD is an instance of either TabularCPD or ContinuousFactor.
#
# ValueError: No CPD associated with fever

# %%
import pandas as pd
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD
import networkx as nx

# Assuming your data is already loaded into data3
# data3 = pd.read_csv('/path/to/your/data3.csv')  # Uncomment and set path as needed

# Constructing the Bayesian Network structure, ensuring no cycles
network_structure = []
directed_graph = nx.DiGraph()

for index, row in data3.iterrows():
    disease = row['MeSH Disease Term'].strip().lower()  # Corrected column name
    symptom = row['MeSH Symptom Term'].strip().lower()  # Corrected column name
    if disease != symptom:  # Ensure disease is not added as its own symptom
        directed_graph.add_edge(disease, symptom)
        if not nx.is_directed_acyclic_graph(directed_graph):
            directed_graph.remove_edge(disease, symptom)

bn_model = BayesianNetwork(directed_graph.edges())

# Adding CPDs to the Bayesian Network based on its structure
for node in bn_model.nodes():
    # Check if the node is a symptom and has diseases as parents
    parents = list(directed_graph.predecessors(node))
    if parents:  # Node is a symptom and has disease parents
        cpd_values = [[0.95 if i % 2 == 0 else 0.05 for i in range(2**len(parents))],
                      [0.05 if i % 2 == 0 else 0.95 for i in range(2**len(parents))]]
        cpd = TabularCPD(variable=node, variable_card=2, values=cpd_values,
                         evidence=parents, evidence_card=[2] * len(parents))
    else:  # Node is a disease or no parents, assign a default prior
        cpd = TabularCPD(variable=node, variable_card=2, values=[[0.5], [0.5]])

    bn_model.add_cpds(cpd)

# Validate the model
if bn_model.check_model():
    print("The Bayesian network is correctly defined and valid.")
else:
    print("There was a problem with the network definition or CPDs.")

print("Nodes in the Bayesian Network:", bn_model.nodes())
print("Edges in the Bayesian Network:", bn_model.edges())

# %%
# Constructing the Bayesian Network structure, ensuring no cycles
network_structure = []
directed_graph = nx.DiGraph()

for index, row in data3.iterrows():
    disease = row['MESH Disease Term'].strip().lower()
    symptom = row['PubMed occurrence'].strip().lower()
    if disease != symptom:
        directed_graph.add_edge(disease, symptom)
        if not nx.is_directed_acyclic_graph(directed_graph):
            directed_graph.remove_edge(disease, symptom)

bn_model = BayesianNetwork(directed_graph.edges())

# Adding CPDs to the Bayesian Network based on its structure
for node in bn_model.nodes():
    # Check if the node is a symptom and has diseases as parents
    parents = list(directed_graph.predecessors(node))
    if parents:  # Node is a symptom and has disease parents
        cpd_values = [[0.95, 0.05] + [0.95, 0.05] * (2 ** len(parents) - 1),  # Generic example values, adjust as needed
                      [0.05, 0.95] + [0.05, 0.95] * (2 ** len(parents) - 1)]
        cpd = TabularCPD(variable=node, variable_card=2, values=cpd_values,
                         evidence=parents, evidence_card=[2] * len(parents))
    else:  # Node is a disease or no parents, assign a default prior
        cpd = TabularCPD(variable=node, variable_card=2, values=[[0.99], [0.01]])

    bn_model.add_cpds(cpd)

# Validate the model
if bn_model.check_model():
    print("The Bayesian network is correctly defined and valid.")
else:
    print("There was a problem with the network definition or CPDs.")

print("Nodes in the Bayesian Network:", bn_model.nodes())
print("Edges in the Bayesian Network:", bn_model.edges())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MESH Disease Term'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-2326e318202e> in <cell line: 5>()
#       4
#       5 for index, row in data3.iterrows():
# ----> 6     disease = row['MESH Disease Term'].strip().lower()
#       7     symptom = row['PubMed occurrence'].strip().lower()
#       8     if disease != symptom:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1114
#    1115         # Similar to Index.get_value, but we do not fall back to positional
# -> 1116         loc = self.index.get_loc(label)
#    1117
#    1118         if is_integer(loc):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'MESH Disease Term'

# %%
bn_structure = []
graph = nx.DiGraph()

for index, row in data3.iterrows():
    disease = row['Disease'].strip().lower()
    symptom = row['Symptom'].strip().lower()
    if disease != symptom:
        # Add edge and check for cycles
        graph.add_edge(disease, symptom)
        if not nx.is_directed_acyclic_graph(graph):
            graph.remove_edge(disease, symptom)

bn_model = BayesianNetwork(graph.edges())

# Adding CPDs
for node in graph.nodes():
    # Find parents of the node within the graph, which indicates dependencies
    parents = list(graph.predecessors(node))
    if not parents:
        # Assuming no parents means it's a root node (disease)
        cpd = TabularCPD(variable=node, variable_card=2, values=[[0.5], [0.5]])
    else:
        # Create a CPD for a symptom with its diseases as evidence
        evidence_card = [2] * len(parents)
        cpd = TabularCPD(variable=node, variable_card=2,
                         values=[[0.95, 0.2], [0.05, 0.8]],
                         evidence=parents, evidence_card=evidence_card)
    bn_model.add_cpds(cpd)

# Validate the model
if bn_model.check_model():
    print("The Bayesian network is correctly defined and valid.")
else:
    print("There was a problem with the network definition or CPDs.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-6ff0f3e2e7fd> in <cell line: 16>()
#      23         # Create a CPD for a symptom with its diseases as evidence
#      24         evidence_card = [2] * len(parents)
# ---> 25         cpd = TabularCPD(variable=node, variable_card=2,
#      26                          values=[[0.95, 0.2], [0.05, 0.8]],
#      27                          evidence=parents, evidence_card=evidence_card)
#
# /usr/local/lib/python3.10/dist-packages/pgmpy/factors/discrete/CPD.py in __init__(self, variable, variable_card, values, evidence, evidence_card, state_names)
#     140             expected_cpd_shape = (variable_card, np.prod(evidence_card))
#     141         if values.shape != expected_cpd_shape:
# --> 142             raise ValueError(
#     143                 f"values must be of shape {expected_cpd_shape}. Got shape: {values.shape}"
#     144             )
#
# ValueError: values must be of shape (2, 16). Got shape: (2, 2)

# %%
network_structure = []
directed_graph = nx.DiGraph()

for index, row in data3.iterrows():
    disease = row['Disease'].strip().lower()
    symptom = row['Symptom'].strip().lower()
    if disease != symptom:
        # Temporarily add edge to check for cycles
        directed_graph.add_edge(disease, symptom)
        if nx.is_directed_acyclic_graph(directed_graph):
            network_structure.append((disease, symptom))
        else:
            # If a cycle is created, remove the edge
            directed_graph.remove_edge(disease, symptom)

# Create the Bayesian Network with the filtered structure
bn_model = BayesianNetwork(network_structure)

# Check nodes and edges to confirm no cycles
print("Nodes in the Bayesian Network:", bn_model.nodes())
print("Edges in the Bayesian Network:", bn_model.edges())

# Assuming filtered_structure is properly set as before and bn_model is created
for disease, symptom in filtered_structure:
    cpd_disease = TabularCPD(variable=disease, variable_card=2, values=[[0.99], [0.01]])
    cpd_symptom_given_disease = TabularCPD(variable=symptom, variable_card=2,
                                           values=[[0.95, 0.2],  # P(Symptom=No | Disease=No), P(Symptom=No | Disease=Yes)
                                                   [0.05, 0.8]], # P(Symptom=Yes | Disease=No), P(Symptom=Yes | Disease=Yes)
                                           evidence=[disease], evidence_card=[2])
    bn_model.add_cpds(cpd_disease, cpd_symptom_given_disease)

# Ensure all nodes have CPDs
for node in bn_model.nodes():
    if not bn_model.get_cpds(node):
        # Assign a default CPD (uniform distribution as an example)
        uniform_cpd = TabularCPD(variable=node, variable_card=2, values=[[0.5], [0.5]])
        bn_model.add_cpds(uniform_cpd)

# Check if the model is valid
if bn_model.check_model():
    print("The Bayesian network is correctly defined and valid.")
else:
    print("There was a problem with the network definition.")

# Validate CPDs
if bn_model.check_model():
    print("CPDs added successfully and the model is valid.")
else:
    print("There was a problem adding CPDs or the model is not valid.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Disease'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-7d945a7032e3> in <cell line: 4>()
#       3
#       4 for index, row in data3.iterrows():
# ----> 5     disease = row['Disease'].strip().lower()
#       6     symptom = row['Symptom'].strip().lower()
#       7     if disease != symptom:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1114
#    1115         # Similar to Index.get_value, but we do not fall back to positional
# -> 1116         loc = self.index.get_loc(label)
#    1117
#    1118         if is_integer(loc):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Disease'

# %%
network_structure = [(row['Disease'].strip().lower(), row['Symptom'].strip().lower())
                     for index, row in data3.iterrows()
                     if row['Disease'].strip().lower() != row['Symptom'].strip().lower()]

# Debug: Check what's in network_structure before filtering
print("Network Structure Pre-filter: ", network_structure)

# Create a directed graph to check for cycles
directed_graph = nx.DiGraph()
directed_graph.add_edges_from(network_structure)

# Check for cycles in the graph
try:
    cycle = nx.find_cycle(directed_graph, orientation='original')
    print("Cycle Found: ", cycle)
except nx.NetworkXNoCycle:
    print("No cycles found.")

# Since no cycles, let's proceed with the original structure
bn_model = BayesianNetwork(network_structure)

# Check nodes and edges
print("Nodes in the Bayesian Network:", bn_model.nodes())
print("Edges in the Bayesian Network:", bn_model.edges())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Disease'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-797fc8cb0810> in <cell line: 1>()
# ----> 1 network_structure = [(row['Disease'].strip().lower(), row['Symptom'].strip().lower())
#       2                      for index, row in data3.iterrows()
#       3                      if row['Disease'].strip().lower() != row['Symptom'].strip().lower()]
#       4
#       5 # Debug: Check what's in network_structure before filtering
#
# <ipython-input-13-797fc8cb0810> in <listcomp>(.0)
#       1 network_structure = [(row['Disease'].strip().lower(), row['Symptom'].strip().lower())
#       2                      for index, row in data3.iterrows()
# ----> 3                      if row['Disease'].strip().lower() != row['Symptom'].strip().lower()]
#       4
#       5 # Debug: Check what's in network_structure before filtering
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1114
#    1115         # Similar to Index.get_value, but we do not fall back to positional
# -> 1116         loc = self.index.get_loc(label)
#    1117
#    1118         if is_integer(loc):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Disease'

# %%
network_structure = [(row['Disease'].strip().lower(), row['Symptom'].strip().lower())
                     for index, row in data3.iterrows()
                     if row['Disease'].strip().lower() != row['Symptom'].strip().lower()]

def would_form_cycle(edges, test_edge):
    directed_graph = nx.DiGraph()
    directed_graph.add_edges_from(edges)
    directed_graph.add_edge(*test_edge)
    try:
        nx.find_cycle(directed_graph, orientation='original')
        return True
    except nx.NetworkXNoCycle:
        return False

# Filter out edges that would form cycles
filtered_structure = [edge for edge in network_structure if not would_form_cycle(network_structure, edge)]

# Create the Bayesian Network with the filtered structure
bn_model = BayesianNetwork(filtered_structure)

# Adding CPDs
for disease, symptom in filtered_structure:
    cpd_disease = TabularCPD(variable=disease, variable_card=2, values=[[0.99], [0.01]])
    cpd_symptom_given_disease = TabularCPD(variable=symptom, variable_card=2,
                                           values=[[0.95, 0.2], [0.05, 0.8]],
                                           evidence=[disease], evidence_card=[2])
    bn_model.add_cpds(cpd_disease, cpd_symptom_given_disease)

# Validate the model
if bn_model.check_model():
    print("The Bayesian network is correctly defined and valid.")
else:
    print("There was a problem adding CPDs or the model is not valid.")

# Display nodes and edges
print("Nodes in the Bayesian Network:", bn_model.nodes())
print("Edges in the Bayesian Network:", bn_model.edges())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Disease'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-98886f62f48f> in <cell line: 1>()
# ----> 1 network_structure = [(row['Disease'].strip().lower(), row['Symptom'].strip().lower())
#       2                      for index, row in data3.iterrows()
#       3                      if row['Disease'].strip().lower() != row['Symptom'].strip().lower()]
#       4
#       5 def would_form_cycle(edges, test_edge):
#
# <ipython-input-14-98886f62f48f> in <listcomp>(.0)
#       1 network_structure = [(row['Disease'].strip().lower(), row['Symptom'].strip().lower())
#       2                      for index, row in data3.iterrows()
# ----> 3                      if row['Disease'].strip().lower() != row['Symptom'].strip().lower()]
#       4
#       5 def would_form_cycle(edges, test_edge):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1114
#    1115         # Similar to Index.get_value, but we do not fall back to positional
# -> 1116         loc = self.index.get_loc(label)
#    1117
#    1118         if is_integer(loc):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Disease'

# %%
import pandas as pd
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD
import networkx as nx

# Assuming data3 is loaded and contains 'Disease' and 'Symptom' columns correctly set
network_structure = [(row['Disease'].strip().lower(), row['Symptom'].strip().lower())
                     for index, row in data3.iterrows()
                     if row['Disease'].strip().lower() != row['Symptom'].strip().lower()]

def would_form_cycle(edges, test_edge):
    directed_graph = nx.DiGraph()
    directed_graph.add_edges_from(edges)
    directed_graph.add_edge(*test_edge)
    try:
        nx.find_cycle(directed_graph, orientation='original')
        return True
    except nx.NetworkXNoCycle:
        return False

# Filter out edges that would form cycles
filtered_structure = [edge for edge in network_structure if not would_form_cycle(network_structure, edge)]

# Create the Bayesian Network with the filtered structure
bn_model = BayesianNetwork(filtered_structure)

# Adding CPDs based on simple probabilities (these should ideally be based on data)
for disease, symptom in filtered_structure:
    cpd_disease = TabularCPD(variable=disease, variable_card=2, values=[[0.99], [0.01]])
    cpd_symptom_given_disease = TabularCPD(variable=symptom, variable_card=2,
                                           values=[[0.95, 0.2],  # P(Symptom=No | Disease=No), P(Symptom=No | Disease=Yes)
                                                   [0.05, 0.8]], # P(Symptom=Yes | Disease=No), P(Symptom=Yes | Disease=Yes)
                                           evidence=[disease], evidence_card=[2])
    bn_model.add_cpds(cpd_disease, cpd_symptom_given_disease)

# Check if the model is valid after adding CPDs
if bn_model.check_model():
    print("CPDs added successfully and the model is valid.")
else:
    print("There was a problem adding CPDs or the model is not valid.")

print("Nodes in the Bayesian Network:", bn_model.nodes())
print("Edges in the Bayesian Network:", bn_model.edges())
# Out:
# CPDs added successfully and the model is valid.
# Nodes in the Bayesian Network: []
# Edges in the Bayesian Network: []

# %%
#Create network

import pandas as pd
from pgmpy.models import BayesianNetwork

#network_structure = []
#for index, row in data3.iterrows():
    #disease = row['Disease'].strip().lower()
    #symptom = row['Symptom'].strip().lower()
    #if disease != symptom:  # This check ensures no self-loops
        #network_structure.append((disease, symptom))

from pgmpy.models import BayesianNetwork
import networkx as nx

# Assuming network_structure contains all intended edges
network_structure = [(row['Disease'].strip().lower(), row['Symptom'].strip().lower()) for index, row in data3.iterrows() if row['Disease'].strip().lower() != row['Symptom'].strip().lower()]
def would_form_cycle(edges, test_edge):
    directed_graph = nx.DiGraph()
    directed_graph.add_edges_from(edges)
    directed_graph.add_edge(*test_edge)
    try:
        # Check for cycles in the graph
        cycle = nx.find_cycle(directed_graph, orientation='original')
        return True
    except nx.NetworkXNoCycle:
        return False

# Filter out edges that would form cycles
filtered_structure = [edge for edge in network_structure if not would_form_cycle(network_structure, edge)]

# Create the Bayesian Network
bn_model = BayesianNetwork(filtered_structure)

# Check if the model is valid
if bn_model.check_model():
    print("The Bayesian network is correctly defined and valid.")
else:
    print("The Bayesian network has errors.")

# Create the Bayesian Network
bn_model = BayesianNetwork(network_structure)

# Check if there are still errors
try:
    bn_model.check_model()
    print("The Bayesian network is correctly defined and valid.")
except Exception as e:
    print(f"Error in the Bayesian network: {str(e)}")

for disease, symptom in network_structure:
    cpd_disease = TabularCPD(variable=disease, variable_card=2, values=[[0.99], [0.01]])
    cpd_symptom_given_disease = TabularCPD(variable=symptom, variable_card=2,
                                           values=[[0.95, 0.2],  # P(Symptom=No | Disease=No), P(Symptom=No | Disease=Yes)
                                                   [0.05, 0.8]], # P(Symptom=Yes | Disease=No), P(Symptom=Yes | Disease=Yes)
                                           evidence=[disease], evidence_card=[2])

    bn_model.add_cpds(cpd_disease, cpd_symptom_given_disease)

# Check if the model is valid after adding CPDs
if bn_model.check_model():
    print("CPDs added successfully and the model is valid.")
else:
    print("There was a problem adding CPDs or the model is not valid.")
# Out:
# The Bayesian network is correctly defined and valid.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/networkx/convert.py in to_networkx_graph(data, create_using, multigraph_input)
#     171         try:
# --> 172             return from_edgelist(data, create_using=create_using)
#     173         except Exception as err:
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/decorators.py in argmap_from_edgelist_1(edgelist, create_using, backend, **backend_kwargs)
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/backends.py in __call__(self, backend, *args, **kwargs)
#     632             # Fast path if no backends are installed
# --> 633             return self.orig_func(*args, **kwargs)
#     634
#
# /usr/local/lib/python3.10/dist-packages/networkx/convert.py in from_edgelist(edgelist, create_using)
#     492     G = nx.empty_graph(0, create_using)
# --> 493     G.add_edges_from(edgelist)
#     494     return G
#
# /usr/local/lib/python3.10/dist-packages/pgmpy/base/DAG.py in add_edges_from(self, ebunch, weights)
#     284             for edge in ebunch:
# --> 285                 self.add_edge(edge[0], edge[1])
#     286
#
# /usr/local/lib/python3.10/dist-packages/pgmpy/models/BayesianNetwork.py in add_edge(self, u, v, **kwargs)
#     121         if u in self.nodes() and v in self.nodes() and nx.has_path(self, v, u):
# --> 122             raise ValueError(
#     123                 "Loops are not allowed. Adding the edge from (%s->%s) forms a loop."
#
# ValueError: Loops are not allowed. Adding the edge from (athetosis->chorea) forms a loop.
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-51-716d9fb8e41a> in <cell line: 42>()
#      40
#      41 # Create the Bayesian Network
# ---> 42 bn_model = BayesianNetwork(network_structure)
#      43
#      44 # Check if there are still errors
#
# /usr/local/lib/python3.10/dist-packages/pgmpy/models/BayesianNetwork.py in __init__(self, ebunch, latents)
#      94
#      95     def __init__(self, ebunch=None, latents=set()):
# ---> 96         super(BayesianNetwork, self).__init__(ebunch=ebunch, latents=latents)
#      97         self.cpds = []
#      98         self.cardinalities = defaultdict(int)
#
# /usr/local/lib/python3.10/dist-packages/pgmpy/base/DAG.py in __init__(self, ebunch, latents)
#      72
#      73     def __init__(self, ebunch=None, latents=set()):
# ---> 74         super(DAG, self).__init__(ebunch)
#      75         self.latents = set(latents)
#      76         cycles = []
#
# /usr/local/lib/python3.10/dist-packages/networkx/classes/digraph.py in __init__(self, incoming_graph_data, **attr)
#     359         # attempt to load graph with data
#     360         if incoming_graph_data is not None:
# --> 361             convert.to_networkx_graph(incoming_graph_data, create_using=self)
#     362         # load graph attributes (must be after convert)
#     363         self.graph.update(attr)
#
# /usr/local/lib/python3.10/dist-packages/networkx/convert.py in to_networkx_graph(data, create_using, multigraph_input)
#     172             return from_edgelist(data, create_using=create_using)
#     173         except Exception as err:
# --> 174             raise nx.NetworkXError("Input is not a valid edge list") from err
#     175
#     176     raise nx.NetworkXError("Input is not a known data type for conversion.")
#
# NetworkXError: Input is not a valid edge list

# %%
#handle the data

if 'MeSH Disease Term' in data1.columns:
    data1.drop(columns=['MeSH Disease Term'], inplace=True)

data1.rename(columns={'Occurences': 'Occurrences'}, inplace=True)  # Correcting spelling mistake

data1.drop(columns=['TFIDF score', 'PubMed occurrence'], inplace=True, errors='ignore')  # 'errors' parameter to avoid KeyError if column doesn't exist

if 'MeSH Disease Term' in data2.columns:
    data2.drop(columns=['MeSH Disease Term'], inplace=True)
data2.rename(columns={'Occurences': 'Occurrences'}, inplace=True)  # Correcting spelling mistake

data2.drop(columns=['TFIDF score', 'PubMed occurrence'], inplace=True, errors='ignore')  # 'errors' parameter to avoid KeyError if column doesn't exist

if 'MeSH Disease Term' in data3.columns:
    data3.drop(columns=['MeSH Disease Term'], inplace=True)

data3.rename(columns={'Occurences': 'Occurrences'}, inplace=True)  # Correcting spelling mistake

data3.drop(columns=['TFIDF score', 'PubMed occurrence'], inplace=True, errors='ignore')  # 'errors' parameter to avoid KeyError if column doesn't exist

# %%
#handle the data

all_data = pd.concat([data1, data2, data3], ignore_index=True)

print(all_data.head())
all_data['MeSH Disease Term'] = all_data['MeSH Disease Term'].str.strip().str.lower()
diseases_over_300 = all_data[all_data['PubMed occurrence'] > 300]

network_structure = set()
for index, row in diseases_over_300.iterrows():
    disease = row['MeSH Disease Term']
    symptom = row['PubMed occurrence']

    if pd.notna(disease) and pd.notna(symptom) and disease != symptom:
        network_structure.add((disease, symptom.lower().strip()))


cleaned_network_structure = set()

for disease, symptom in network_structure:
    if pd.notna(disease) and pd.notna(symptom) and disease != symptom:
        cleaned_network_structure.add((disease, symptom))

all_diseases_in_data = set(all_data['MeSH Disease Term'].unique())
diseases_in_network = set(disease for disease, symptom in cleaned_network_structure)

# Diseases in the network not in the data (missing CPDs potential)
missing_cpd_diseases = diseases_in_network - all_diseases_in_data
print(missing_cpd_diseases)
# Out:
#                    Disease  Occurrences MeSH Symptom Term
# 0         Breast Neoplasms     122226.0               NaN
# 1             Hypertension     107294.0               NaN
# 2  Coronary Artery Disease      82819.0               NaN
# 3           Lung Neoplasms      78009.0               NaN
# 4    Myocardial Infarction      75945.0               NaN
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MeSH Disease Term'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-f6de68aa066b> in <cell line: 6>()
#       4
#       5 print(all_data.head())
# ----> 6 all_data['MeSH Disease Term'] = all_data['MeSH Disease Term'].str.strip().str.lower()
#       7 diseases_over_300 = all_data[all_data['PubMed occurrence'] > 300]
#       8
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'MeSH Disease Term'

# %%
#filter only for the instances with over 300
diseases_over_300 = all_data[all_data['PubMed occurrence'] > 300]

network_structure = set()  # Use a set to automatically handle duplicates

# Iterate through diseases to associate symptoms
current_disease = None
for index, row in diseases_over_300.iterrows():
    if row['PubMed occurrence'] > 3000:
        current_disease = row['MeSH Disease Term']
    elif current_disease and pd.notna(row['MeSH Symptom Term']):
        symptom = row['MeSH Symptom Term']
        if current_disease != symptom:  # Ensure no self-loops
            # Add (Disease, Symptom) tuple to the network structure
            network_structure.add((current_disease, symptom))

# Convert the set back to a list to create the Bayesian Network
network_structure = list(network_structure)

# Create the Bayesian Network with the structure determined from data
model = BayesianNetwork(network_structure)

# Validate the model
if model.check_model():
    print("The Bayesian model is correctly defined.")
else:
    print("The model has errors.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-ebb60efb92d3> in <cell line: 24>()
#      22
#      23 # Validate the model
# ---> 24 if model.check_model():
#      25     print("The Bayesian model is correctly defined.")
#      26 else:
#
# /usr/local/lib/python3.10/dist-packages/pgmpy/models/BayesianNetwork.py in check_model(self)
#     407             # Check if a CPD is associated with every node.
#     408             if cpd is None:
# --> 409                 raise ValueError(f"No CPD associated with {node}")
#     410
#     411             # Check if the CPD is an instance of either TabularCPD or ContinuousFactor.
#
# ValueError: No CPD associated with paraplegia

# %%
# Assuming you have a way to get occurrence data for each disease
disease_occurrences = diseases_over_300[diseases_over_300['PubMed occurrence'] > 3000].set_index('MeSH Disease Term')['PubMed occurrence']
total_occurrences = disease_occurrences.sum()

# Define priors for diseases
for disease in disease_occurrences.index:
    prior_probability = disease_occurrences[disease] / total_occurrences
    cpd_disease = TabularCPD(variable=disease, variable_card=2,
                             values=[[1 - prior_probability], [prior_probability]])
    model.add_cpds(cpd_disease)

# Example for defining symptom probabilities based on disease presence
for (disease, symptom) in network_structure:
    # You need data here to specify these probabilities
    cpd_symptom = TabularCPD(variable=symptom, variable_card=2,
                             values=[[0.95, 0.2],  # Probability of not having symptom given disease absence or presence
                                     [0.05, 0.8]], # Probability of having symptom given disease absence or presence
                             evidence=[disease], evidence_card=[2])
    model.add_cpds(cpd_symptom)

try:
    assert model.check_model()
    print("The Bayesian model is correctly defined.")
except ValueError as e:
    print(f"Model validation failed: {e}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-eae3aff7a141> in <cell line: 6>()
#       8     cpd_disease = TabularCPD(variable=disease, variable_card=2,
#       9                              values=[[1 - prior_probability], [prior_probability]])
# ---> 10     model.add_cpds(cpd_disease)
#      11
#      12 # Example for defining symptom probabilities based on disease presence
#
# /usr/local/lib/python3.10/dist-packages/pgmpy/models/BayesianNetwork.py in add_cpds(self, *cpds)
#     257
#     258             if set(cpd.scope()) - set(cpd.scope()).intersection(set(self.nodes())):
# --> 259                 raise ValueError("CPD defined on variable not in the model", cpd)
#     260
#     261             for prev_cpd_index in range(len(self.cpds)):
#
# ValueError: ('CPD defined on variable not in the model', <TabularCPD representing P(Breast Neoplasms:2) at 0x78c5fc39b880>)

# %%
# Calculate total occurrences of diseases
total_disease_occurrences = diseases_over_300[diseases_over_300['PubMed occurrence'] > 3000]['PubMed occurrence'].sum()

# Initialize dictionary for priors
disease_priors = {}

# Calculate priors for each disease
for index, row in diseases_over_300.iterrows():
    if row['PubMed occurrence'] > 3000:
        disease = row['MeSH Disease Term']
        disease_priors[disease] = row['PubMed occurrence'] / total_disease_occurrences

# Convert priors to TabularCPD objects for pgmpy
from pgmpy.factors.discrete import TabularCPD
disease_cpds = []
for disease, prior in disease_priors.items():
    cpd = TabularCPD(variable=disease, variable_card=2, values=[[1-prior], [prior]])
    disease_cpds.append(cpd)
    model.add_cpds(cpd)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-b7e2b4ad1816> in <cell line: 16>()
#      17     cpd = TabularCPD(variable=disease, variable_card=2, values=[[1-prior], [prior]])
#      18     disease_cpds.append(cpd)
# ---> 19     model.add_cpds(cpd)
#
# /usr/local/lib/python3.10/dist-packages/pgmpy/models/BayesianNetwork.py in add_cpds(self, *cpds)
#     257
#     258             if set(cpd.scope()) - set(cpd.scope()).intersection(set(self.nodes())):
# --> 259                 raise ValueError("CPD defined on variable not in the model", cpd)
#     260
#     261             for prev_cpd_index in range(len(self.cpds)):
#
# ValueError: ('CPD defined on variable not in the model', <TabularCPD representing P(Breast Neoplasms:2) at 0x78c5fc399f90>)
